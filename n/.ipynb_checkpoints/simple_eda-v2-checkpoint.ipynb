# %%
import os
import time
import gc
import json
import requests
from datetime import date, timedelta, datetime

import pandas as pd
import numpy as np
import io
from pandas.io.json import json_normalize

# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings('ignore')

pd.options.display.float_format = "{:.2f}".format
pd.set_option('display.html.use_mathjax', False) # от italic шрифтов

import ujson
import rapidjson
import orjson

# %%
dump_arr = {}

def benchmark(name, dumps):
    start = time.time()
    for i in range(500):
        dumps(data)
    print(name, time.time() - start)
    dump_arr.update({name : time.time() - start})
        

benchmark("Python default: ", json.dumps)
# orjson only outputs bytes, but often we need unicode:
benchmark("orjson: ", lambda s: str(orjson.dumps(s), "utf-8"))
benchmark("rapidjson: ", rapidjson.dumps)
benchmark("ujson: ", ujson.dumps)
# Out:
# Python default:  26.740447521209717
# orjson:  5.626964330673218
# rapidjson:  14.048872470855713
# ujson:  13.809800148010254

# %%
dump_arr
# Out:
# {'Python default: ': 26.740865230560303,
#  'orjson: ': 5.627078294754028,
#  'rapidjson: ': 14.048988819122314,
#  'ujson: ': 13.809906244277954}

# %%
list(dump_arr.keys())
# Out:
# ['Python default: ', 'orjson: ', 'rapidjson: ', 'ujson: ']

# %%
plt.barh(list(dump_arr.keys()), dump_arr.values(), align='center')
# Out:
# <BarContainer object of 4 artists>

# %%
load_arr = {}
def load_benchmark(name, json_type):
    start = time.time()
    for i in range(100):
        with open(PATH, encoding="utf8") as f:
            json_type(f)
    print(name, time.time() - start)
    load_arr.update({name : 1/(time.time() - start)})

# %%
load_benchmark("Python default: ", json.load)
# orjson only outputs bytes, but often we need unicode:
load_benchmark("orjson: ",  lambda s:[orjson.loads(line) for line in s.readlines()]) #convert string to dict format)
load_benchmark("rapidjson: ", rapidjson.load)
load_benchmark("ujson: ", ujson.load)
# Out:
# Python default:  8.514800071716309
# orjson:  7.503512382507324
# rapidjson:  10.906418085098267
# ujson:  8.531050682067871

# %%
pos = np.arange(len(load_arr.keys()))
width = 0.3     # gives histogram aspect to the bar diagram

ax = plt.axes()
ax.set_xticks(pos + (width / 30))
ax.set_xticklabels(load_arr.keys())

plt.bar(load_arr.keys(), load_arr.values(), width, color='green')
# Out:
# <BarContainer object of 4 artists>

# %%
print('{:%d, %b %Y}'.format(l))
# Out:
# 10, Jan 2019

# %%
datetime.strftime(l, '%d, %b %Y')
# Out:
# '10, Jan 2019'

# %%
date = '10/24/2019'

# %%
def get_data_rg(start_date, end_date):
    '''FORMAT: MM/DD/YYYY eg. '10/24/2019'
    '''
    json_arr = []
    sdate = datetime.strptime(start_date, '%m/%d/%Y')
    edate = datetime.strptime(end_date, '%m/%d/%Y')
    delta = edate - sdate
    for i in range(delta.days+1):
        day = sdate + timedelta(days=i)
        date_day = datetime.strftime(day, '%m/%d/%Y')
        response = requests.get('https://resultsdb-api.rotogrinders.com/api/contests?start='+date_day+'&lean=true')
        data = response.json()
        json_arr = json_arr + data
        time.sleep(1)
    with open('RG_{}_{}.json'.format(sdate, edate), 'w') as outfile:
        json.dump(json_arr, outfile)
    return json_arr


'''def map_sport(sportname):
    sportname = sportname.lower()
    if sportname == 'nfl':
        return 1
    if sportname == 'mlb':
        return 2
    if sportname == 'nba':
        return 3
    if sportname == 'nhl':
        return 4
    if sportname == 'golf' or sportname == 'apt':
        return 6
    return ValueError('Sport type is not tracked')
'''

def df_prep(json_data):
    df = pd.DataFrame(json_data, columns = ['name',
                                            'sport',
                                            'gameCount',
                                            'start',                                       
                                            'prizePool',
                                            'entryFee',
                                            'maxEntriesPerUser',
                                            'maxEntries',
                                            'entryCount'
                                           ])
    df['sport'] = df['sport'].map({1:'NFL',
                                   2:'MLB',
                                   3:'NBA',
                                   4:'NHL',
                                   6:'GOLF'})
    df['start'] = df['start'].apply(lambda x:x[:-1])
    df['start'] = pd.to_datetime(df['start'])
    df.insert(3, 'dayofweek', df['start'].dt.day_name())
    df.dropna(inplace=True) # Если нет mE и mEPerUser, на сайте игр нет, хотя в логах played=true. Если нет gameCount - отмененные. 
    df['maxEntries'] = df['maxEntries'].astype('int')
    df['maxEntriesPerUser'] = df['maxEntriesPerUser'].astype('int')
    df['name'] = df['name'].str.lower()
    return df

def rg_df(PATH):
    '''Supported sport types are:
    NFL, NBA, MLB, NHL, Golf
    '''
    with open(PATH, encoding="utf8") as f:
        data = f.readlines()
        data = [json.loads(line) for line in data] #convert string to dict format
    df = df_prep(data[0])
    return df

# %%
PATH = 'RG_10-24-19_11-07-19.json'
with open(PATH, encoding="utf8") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'_id': '5db22d5dff66cb78f1d4e892',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 25000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1149,
#   'entryFee': 25,
#   'name': 'NBA Single Entry $25 Double Up ',
#   'siteContestId': '79073448',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 1150,
#   'rgPrizePool': 7750,
#   'rgPrizeWinnerCount': 155,
#   'complete': True,
#   'prizes': [{'cash': 50,
#     'maxFinish': 500,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50}]},
#  {'_id': '5db22d5e9fa90078e9c2676b',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 450000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 52941,
#   'entryFee': 10,
#   'name': 'NBA $450K Big Jam [$100K to 1st]',
#   'siteContestId': '79074503',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 51692,
#   'rgPrizePool': 132410.90000000008,
#   'rgPrizeWinnerCount': 3985,
#   'complete': True,
#   'prizes': [{'cash': 100000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$100,000.00'},
#     'value': 100000},
#    {'cash': 40000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$40,000.00'},
#     'value': 40000},
#    {'cash': 20000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'value': 20000},
#    {'cash': 10000,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'value': 10000},
#    {'cash': 4000,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'value': 4000},
#    {'cash': 3000,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2000,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1500,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1000,
#     'maxFinish': 12,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 700,
#     'maxFinish': 15,
#     'minFinish': 13,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'value': 700},
#    {'cash': 600,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 500,
#     'maxFinish': 25,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 35,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 60,
#     'minFinish': 36,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 90,
#     'minFinish': 61,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 120,
#     'minFinish': 91,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 160,
#     'minFinish': 121,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 70,
#     'maxFinish': 210,
#     'minFinish': 161,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'value': 70},
#    {'cash': 60,
#     'maxFinish': 280,
#     'minFinish': 211,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 380,
#     'minFinish': 281,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 530,
#     'minFinish': 381,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 35,
#     'maxFinish': 780,
#     'minFinish': 531,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'value': 35},
#    {'cash': 30,
#     'maxFinish': 1280,
#     'minFinish': 781,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 2440,
#     'minFinish': 1281,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 5100,
#     'minFinish': 2441,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 12150,
#     'minFinish': 5101,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15}]},
#  {'_id': '5db22d613ef5d178e39b4443',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 15000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 3448,
#   'entryFee': 5,
#   'name': 'NBA Single Entry $5 Double Up',
#   'siteContestId': '79073452',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 3449,
#   'rgPrizePool': 4310,
#   'rgPrizeWinnerCount': 431,
#   'complete': True,
#   'prizes': [{'cash': 10,
#     'maxFinish': 1500,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10}]},
#  {'_id': '5db22dd13ef5d178e39b5220',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 26,
#   'entryFee': 250,
#   'name': 'NBA $250 Double Up',
#   'siteContestId': '79073426',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 27,
#   'rgPrizePool': 3000,
#   'rgPrizeWinnerCount': 6,
#   'complete': True,
#   'prizes': [{'cash': 500,
#     'maxFinish': 12,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500}]},
#  {'_id': '5db22dd1ff66cb78f1d4ed74',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 100000,
#   'maxEntriesPerUser': 79,
#   'maxEntries': 2650,
#   'entryFee': 44,
#   'name': 'NBA $100K Spin Move [10% to 1st]',
#   'siteContestId': '79074502',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 2255,
#   'rgPrizePool': 41824.16,
#   'rgPrizeWinnerCount': 303,
#   'complete': True,
#   'prizes': [{'cash': 10000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'value': 10000},
#    {'cash': 6000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$6,000.00'},
#     'value': 6000},
#    {'cash': 4000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'value': 4000},
#    {'cash': 3000,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2500,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'value': 2500},
#    {'cash': 2000,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1500,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1000,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 750,
#     'maxFinish': 12,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'value': 750},
#    {'cash': 500,
#     'maxFinish': 15,
#     'minFinish': 13,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 350,
#     'maxFinish': 30,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 300,
#     'maxFinish': 50,
#     'minFinish': 31,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 250,
#     'maxFinish': 70,
#     'minFinish': 51,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'value': 250},
#    {'cash': 200,
#     'maxFinish': 100,
#     'minFinish': 71,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 130,
#     'minFinish': 101,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 120,
#     'maxFinish': 170,
#     'minFinish': 131,
#     'tierPayoutDescriptions': {'Cash': '$120.00'},
#     'value': 120},
#    {'cash': 100,
#     'maxFinish': 235,
#     'minFinish': 171,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 90,
#     'maxFinish': 335,
#     'minFinish': 236,
#     'tierPayoutDescriptions': {'Cash': '$90.00'},
#     'value': 90},
#    {'cash': 80,
#     'maxFinish': 550,
#     'minFinish': 336,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80}]},
#  {'_id': '5db22dd29fa90078e9c331bb',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 75000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 22294,
#   'entryFee': 4,
#   'name': 'NBA $75K Four Point Play [20 Entry Max, 2X Min Cash]',
#   'siteContestId': '79074504',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 22295,
#   'rgPrizePool': 20829.01,
#   'rgPrizeWinnerCount': 1583,
#   'complete': True,
#   'prizes': [{'cash': 5000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'value': 5000},
#    {'cash': 2500,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'value': 2500},
#    {'cash': 2000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1500,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1000,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 800,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'value': 800},
#    {'cash': 700,
#     'maxFinish': 7,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'value': 700},
#    {'cash': 600,
#     'maxFinish': 8,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 500,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 25,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 100,
#     'maxFinish': 35,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 70,
#     'maxFinish': 45,
#     'minFinish': 36,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'value': 70},
#    {'cash': 60,
#     'maxFinish': 65,
#     'minFinish': 46,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 85,
#     'minFinish': 66,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 125,
#     'minFinish': 86,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 175,
#     'minFinish': 126,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 275,
#     'minFinish': 176,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 475,
#     'minFinish': 276,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 875,
#     'minFinish': 476,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 12,
#     'maxFinish': 1375,
#     'minFinish': 876,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'value': 12},
#    {'cash': 10,
#     'maxFinish': 2405,
#     'minFinish': 1376,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 8,
#     'maxFinish': 4855,
#     'minFinish': 2406,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8}]},
#  {'_id': '5db22dd332c41378eff52f81',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 300000,
#   'maxEntriesPerUser': 45,
#   'maxEntries': 1501,
#   'entryFee': 222,
#   'name': 'NBA $300K SLAM Jam [$100K to 1st]',
#   'siteContestId': '79074506',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 1391,
#   'rgPrizePool': 197116.66999999998,
#   'rgPrizeWinnerCount': 157,
#   'complete': True,
#   'prizes': [{'cash': 100000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$100,000.00'},
#     'value': 100000},
#    {'cash': 30000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$30,000.00'},
#     'value': 30000},
#    {'cash': 20000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'value': 20000},
#    {'cash': 10000,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'value': 10000},
#    {'cash': 5000,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'value': 5000},
#    {'cash': 3000,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2000,
#     'maxFinish': 7,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1500,
#     'maxFinish': 8,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1000,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 750,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'value': 750},
#    {'cash': 600,
#     'maxFinish': 25,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 500,
#     'maxFinish': 55,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 130,
#     'minFinish': 56,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 350,
#     'maxFinish': 335,
#     'minFinish': 131,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350}]},
#  {'_id': '5db22e1aff66cb78f1d4f6a7',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 50000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 10,
#   'entryFee': 5300,
#   'name': 'NBA $50K Thunderdome [Single Entry]',
#   'siteContestId': '79074500',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 11,
#   'rgPrizePool': 40000,
#   'rgPrizeWinnerCount': 2,
#   'complete': True,
#   'prizes': [{'cash': 25000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$25,000.00'},
#     'value': 25000},
#    {'cash': 15000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$15,000.00'},
#     'value': 15000},
#    {'cash': 10000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'value': 10000}]},
#  {'_id': '5db22e1a32c41378eff53554',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 70000,
#   'maxEntriesPerUser': 2,
#   'maxEntries': 70,
#   'entryFee': 1060,
#   'name': 'NBA $70K All Star [2 Entry Max]',
#   'siteContestId': '79074499',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 68,
#   'rgPrizePool': 34000,
#   'rgPrizeWinnerCount': 9,
#   'complete': True,
#   'prizes': [{'cash': 20000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'value': 20000},
#    {'cash': 10000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'value': 10000},
#    {'cash': 8000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$8,000.00'},
#     'value': 8000},
#    {'cash': 6000,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$6,000.00'},
#     'value': 6000},
#    {'cash': 4000,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'value': 4000},
#    {'cash': 3000,
#     'maxFinish': 9,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2000,
#     'maxFinish': 14,
#     'minFinish': 10,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000}]},
#  {'_id': '5db22e1a9fa90078e9c38936',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 50000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 370,
#   'entryFee': 150,
#   'name': 'NBA $50K Posterizer [3 Entry Max]',
#   'siteContestId': '79073432',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 326,
#   'rgPrizePool': 23625,
#   'rgPrizeWinnerCount': 49,
#   'complete': True,
#   'prizes': [{'cash': 5000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'value': 5000},
#    {'cash': 3000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2500,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'value': 2500},
#    {'cash': 2000,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1500,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1250,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$1,250.00'},
#     'value': 1250},
#    {'cash': 1000,
#     'maxFinish': 9,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 750,
#     'maxFinish': 15,
#     'minFinish': 10,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'value': 750},
#    {'cash': 500,
#     'maxFinish': 23,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 350,
#     'maxFinish': 38,
#     'minFinish': 24,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 300,
#     'maxFinish': 63,
#     'minFinish': 39,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 250,
#     'maxFinish': 105,
#     'minFinish': 64,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'value': 250}]},
#  {'_id': '5db22e1a3ef5d178e39b529f',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 75000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 44589,
#   'entryFee': 2,
#   'name': 'NBA $75K mini-MAX [150 Entry Max]',
#   'siteContestId': '79074507',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 44550,
#   'rgPrizePool': 25323.01000000002,
#   'rgPrizeWinnerCount': 3967,
#   'complete': True,
#   'prizes': [{'cash': 4000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'value': 4000},
#    {'cash': 3000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1500,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1000,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 700,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'value': 700},
#    {'cash': 500,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 100,
#     'maxFinish': 30,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 70,
#     'maxFinish': 40,
#     'minFinish': 31,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'value': 70},
#    {'cash': 50,
#     'maxFinish': 50,
#     'minFinish': 41,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 60,
#     'minFinish': 51,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 35,
#     'maxFinish': 80,
#     'minFinish': 61,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'value': 35},
#    {'cash': 30,
#     'maxFinish': 110,
#     'minFinish': 81,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 150,
#     'minFinish': 111,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 200,
#     'minFinish': 151,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 275,
#     'minFinish': 201,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 12,
#     'maxFinish': 350,
#     'minFinish': 276,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'value': 12},
#    {'cash': 10,
#     'maxFinish': 430,
#     'minFinish': 351,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 9,
#     'maxFinish': 580,
#     'minFinish': 431,
#     'tierPayoutDescriptions': {'Cash': '$9.00'},
#     'value': 9},
#    {'cash': 8,
#     'maxFinish': 980,
#     'minFinish': 581,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8},
#    {'cash': 7,
#     'maxFinish': 1780,
#     'minFinish': 981,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'value': 7},
#    {'cash': 6,
#     'maxFinish': 2780,
#     'minFinish': 1781,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'value': 6},
#    {'cash': 5,
#     'maxFinish': 4278,
#     'minFinish': 2781,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'value': 5},
#    {'cash': 4.5,
#     'maxFinish': 6908,
#     'minFinish': 4279,
#     'tierPayoutDescriptions': {'Cash': '$4.50'},
#     'value': 4.5},
#    {'cash': 4,
#     'maxFinish': 10408,
#     'minFinish': 6909,
#     'tierPayoutDescriptions': {'Cash': '$4.00'},
#     'value': 4}]},
#  {'_id': '5db232753ef5d178e39c0109',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 3,
#   'siteSlateId': '30807',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 40000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1166,
#   'entryFee': 40,
#   'name': 'NBA $40K Mid Range Jumper [Single Entry]',
#   'siteContestId': '79073440',
#   '_slateId': '5db22d5dff66cb78f1d4e82d',
#   'entryCount': 1167,
#   'rgPrizePool': 9787.5,
#   'rgPrizeWinnerCount': 88,
#   'complete': True,
#   'prizes': [{'cash': 4000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'value': 4000},
#    {'cash': 2500,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'value': 2500},
#    {'cash': 1500,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1000,
#     'maxFinish': 5,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 750,
#     'maxFinish': 8,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'value': 750},
#    {'cash': 500,
#     'maxFinish': 11,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 15,
#     'minFinish': 12,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 26,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 41,
#     'minFinish': 27,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 120,
#     'maxFinish': 71,
#     'minFinish': 42,
#     'tierPayoutDescriptions': {'Cash': '$120.00'},
#     'value': 120},
#    {'cash': 100,
#     'maxFinish': 111,
#     'minFinish': 72,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 80,
#     'maxFinish': 176,
#     'minFinish': 112,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80},
#    {'cash': 60,
#     'maxFinish': 291,
#     'minFinish': 177,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60}]},
#  {'_id': '5db233379fa90078e9c38a9a',
#   'winner': {'score': None, 'users': []},
#   'slateType': 73,
#   'gameCount': 3,
#   'siteSlateId': '30811',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 3,
#   'prizePool': 25000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 5945,
#   'entryFee': 5,
#   'name': 'NBA Tiers $25K Zone [$5K to 1st]',
#   'siteContestId': '79073458',
#   '_slateId': '5db233379fa90078e9c38a7c',
#   'entryCount': 5946,
#   'rgPrizePool': 5946.149999999999,
#   'rgPrizeWinnerCount': 301,
#   'complete': True,
#   'prizes': [{'cash': 5000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'value': 5000},
#    {'cash': 2000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 800,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'value': 800},
#    {'cash': 650,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$650.00'},
#     'value': 650},
#    {'cash': 500,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 350,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 250,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'value': 250},
#    {'cash': 150,
#     'maxFinish': 12,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 15,
#     'minFinish': 13,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 50,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 30,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 50,
#     'minFinish': 31,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 75,
#     'minFinish': 51,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 125,
#     'minFinish': 76,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 230,
#     'minFinish': 126,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 10,
#     'maxFinish': 530,
#     'minFinish': 231,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 8,
#     'maxFinish': 1255,
#     'minFinish': 531,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8}]},
#  {'_id': '5db30c850e7fda7fd08ddb81',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1426,
#   'entryFee': 5,
#   'name': 'NHL $6K One-Timer [Single Entry, $1K to 1st]',
#   'siteContestId': '79060217',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 1378,
#   'rgPrizePool': 2929,
#   'rgPrizeWinnerCount': 96,
#   'complete': True,
#   'prizes': [{'cash': 1000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 500,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 200,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 125,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'value': 125},
#    {'cash': 100,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 80,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80},
#    {'cash': 60,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 25,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 35,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 20,
#     'maxFinish': 50,
#     'minFinish': 36,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 75,
#     'minFinish': 51,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 10,
#     'maxFinish': 137,
#     'minFinish': 76,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 8,
#     'maxFinish': 312,
#     'minFinish': 138,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8}]},
#  {'_id': '5db30c882dc8f57fc277d70c',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 5200,
#   'maxEntriesPerUser': 2,
#   'maxEntries': 67,
#   'entryFee': 88,
#   'name': 'NHL $5.2K Power Forward [2 Entry Max]',
#   'siteContestId': '79060125',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 66,
#   'rgPrizePool': 4024,
#   'rgPrizeWinnerCount': 13,
#   'complete': True,
#   'prizes': [{'cash': 1000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 800,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'value': 800},
#    {'cash': 600,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 400,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 6,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 250,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'value': 250},
#    {'cash': 210,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$210.00'},
#     'value': 210},
#    {'cash': 176,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$176.00'},
#     'value': 176}]},
#  {'_id': '5db30c891f81ae7fc75ab88a',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 294,
#   'entryFee': 20,
#   'name': 'NHL $5K Cross Check [3 Entry Max]',
#   'siteContestId': '79060123',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 258,
#   'rgPrizePool': 3720,
#   'rgPrizeWinnerCount': 53,
#   'complete': True,
#   'prizes': [{'cash': 600,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 400,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 90,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$90.00'},
#     'value': 90},
#    {'cash': 80,
#     'maxFinish': 12,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80},
#    {'cash': 70,
#     'maxFinish': 16,
#     'minFinish': 13,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'value': 70},
#    {'cash': 60,
#     'maxFinish': 24,
#     'minFinish': 17,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 39,
#     'minFinish': 25,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 70,
#     'minFinish': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40}]},
#  {'_id': '5db30c8a0e7fda7fd08de68f',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 8000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 784,
#   'entryFee': 12,
#   'name': 'NHL $8K Knuckle Puck [$2K to 1st, Single Entry]',
#   'siteContestId': '79060214',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 680,
#   'rgPrizePool': 1043.5,
#   'rgPrizeWinnerCount': 45,
#   'complete': True,
#   'prizes': [{'cash': 2000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 500,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 307,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$307.00'},
#     'value': 307},
#    {'cash': 200,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 125,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'value': 125},
#    {'cash': 100,
#     'maxFinish': 7,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 80,
#     'maxFinish': 9,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80},
#    {'cash': 60,
#     'maxFinish': 12,
#     'minFinish': 10,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 18,
#     'minFinish': 13,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 26,
#     'minFinish': 19,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 41,
#     'minFinish': 27,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 24,
#     'maxFinish': 80,
#     'minFinish': 42,
#     'tierPayoutDescriptions': {'Cash': '$24.00'},
#     'value': 24},
#    {'cash': 18,
#     'maxFinish': 159,
#     'minFinish': 81,
#     'tierPayoutDescriptions': {'Cash': '$18.00'},
#     'value': 18}]},
#  {'_id': '5db30c8a2dc8f57fc277da1a',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 229,
#   'entryFee': 25,
#   'name': 'NHL Single Entry $25 Double Up',
#   'siteContestId': '79060711',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 230,
#   'rgPrizePool': 1950,
#   'rgPrizeWinnerCount': 39,
#   'complete': True,
#   'prizes': [{'cash': 50,
#     'maxFinish': 100,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50}]},
#  {'_id': '5db30c8b2dc8f57fc277dce7',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 25000,
#   'maxEntriesPerUser': 26,
#   'maxEntries': 883,
#   'entryFee': 33,
#   'name': 'NHL $25K Line Change [$5K to 1st]',
#   'siteContestId': '79076836',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 833,
#   'rgPrizePool': 18205,
#   'rgPrizeWinnerCount': 138,
#   'complete': True,
#   'prizes': [{'cash': 5000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'value': 5000},
#    {'cash': 2000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 750,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'value': 750},
#    {'cash': 600,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 500,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 7,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 8,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 250,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'value': 250},
#    {'cash': 200,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 35,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 75,
#     'maxFinish': 65,
#     'minFinish': 36,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'value': 75},
#    {'cash': 60,
#     'maxFinish': 125,
#     'minFinish': 66,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 222,
#     'minFinish': 126,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50}]},
#  {'_id': '5db30c8c0e7fda7fd08dec03',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 80000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 9411,
#   'entryFee': 10,
#   'name': 'NHL $80K Twine [$20K to 1st]',
#   'siteContestId': '79076835',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 8500,
#   'rgPrizePool': 41903.33,
#   'rgPrizeWinnerCount': 1334,
#   'complete': True,
#   'prizes': [{'cash': 20000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'value': 20000},
#    {'cash': 7000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$7,000.00'},
#     'value': 7000},
#    {'cash': 3000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2000,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1000,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 700,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'value': 700},
#    {'cash': 500,
#     'maxFinish': 7,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 300,
#     'maxFinish': 8,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 25,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 70,
#     'maxFinish': 45,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'value': 70},
#    {'cash': 60,
#     'maxFinish': 75,
#     'minFinish': 46,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 125,
#     'minFinish': 76,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 200,
#     'minFinish': 126,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 315,
#     'minFinish': 201,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 545,
#     'minFinish': 316,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 1045,
#     'minFinish': 546,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 2075,
#     'minFinish': 1046,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15}]},
#  {'_id': '5db30c8d2dc8f57fc277e3d9',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 11890,
#   'entryFee': 0.5,
#   'name': 'NHL $5K mini-MAX [$1K to 1st, 150 Entry Max]',
#   'siteContestId': '79060126',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 11891,
#   'rgPrizePool': 3526,
#   'rgPrizeWinnerCount': 1536,
#   'complete': True,
#   'prizes': [{'cash': 1000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 350,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 200,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 100,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 50,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 30,
#     'maxFinish': 7,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 20,
#     'maxFinish': 10,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 13,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 10,
#     'maxFinish': 18,
#     'minFinish': 14,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 8,
#     'maxFinish': 28,
#     'minFinish': 19,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8},
#    {'cash': 6,
#     'maxFinish': 48,
#     'minFinish': 29,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'value': 6},
#    {'cash': 5,
#     'maxFinish': 73,
#     'minFinish': 49,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'value': 5},
#    {'cash': 4,
#     'maxFinish': 103,
#     'minFinish': 74,
#     'tierPayoutDescriptions': {'Cash': '$4.00'},
#     'value': 4},
#    {'cash': 3,
#     'maxFinish': 183,
#     'minFinish': 104,
#     'tierPayoutDescriptions': {'Cash': '$3.00'},
#     'value': 3},
#    {'cash': 2,
#     'maxFinish': 383,
#     'minFinish': 184,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'value': 2},
#    {'cash': 1,
#     'maxFinish': 2383,
#     'minFinish': 384,
#     'tierPayoutDescriptions': {'Cash': '$1.00'},
#     'value': 1}]},
#  {'_id': '5db30c8e2dc8f57fc277e6a6',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 8100,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 13,
#   'entryFee': 691,
#   'name': 'NHL $8.1K Crease Master',
#   'siteContestId': '79076834',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 14,
#   'rgPrizePool': 8100,
#   'rgPrizeWinnerCount': 3,
#   'complete': True,
#   'prizes': [{'cash': 4000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'value': 4000},
#    {'cash': 2600,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$2,600.00'},
#     'value': 2600},
#    {'cash': 1500,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500}]},
#  {'_id': '5db30c920e7fda7fd08e1003',
#   'winner': {'score': None, 'users': []},
#   'slateType': 125,
#   'gameCount': 10,
#   'siteSlateId': '30812',
#   'start': '2019-10-24T23:00:00.000Z',
#   'sport': 4,
#   'prizePool': 8500,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 78,
#   'entryFee': 121,
#   'name': 'NHL $8.5K Short-Handed Goal [$2K to 1st, Single Entry]',
#   'siteContestId': '79060215',
#   '_slateId': '5db30c830e7fda7fd08dd86c',
#   'entryCount': 79,
#   'rgPrizePool': 4525,
#   'rgPrizeWinnerCount': 7,
#   'complete': True,
#   'prizes': [{'cash': 2000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1200,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$1,200.00'},
#     'value': 1200},
#    {'cash': 800,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'value': 800},
#    {'cash': 600,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 500,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 350,
#     'maxFinish': 7,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 300,
#     'maxFinish': 9,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 275,
#     'maxFinish': 11,
#     'minFinish': 10,
#     'tierPayoutDescriptions': {'Cash': '$275.00'},
#     'value': 275},
#    {'cash': 250,
# ...
#     'minFinish': 20,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 39,
#     'minFinish': 30,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 59,
#     'minFinish': 40,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 10,
#     'maxFinish': 89,
#     'minFinish': 60,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 8,
#     'maxFinish': 139,
#     'minFinish': 90,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8},
#    {'cash': 6,
#     'maxFinish': 289,
#     'minFinish': 140,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'value': 6},
#    {'cash': 5,
#     'maxFinish': 584,
#     'minFinish': 290,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'value': 5},
#    {'cash': 4,
#     'maxFinish': 1434,
#     'minFinish': 585,
#     'tierPayoutDescriptions': {'Cash': '$4.00'},
#     'value': 4},
#    {'cash': 3,
#     'maxFinish': 3584,
#     'minFinish': 1435,
#     'tierPayoutDescriptions': {'Cash': '$3.00'},
#     'value': 3},
#    {'cash': 2,
#     'maxFinish': 8584,
#     'minFinish': 3585,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'value': 2}]},
#  {'_id': '5db9bcca08f5472d9c215db9',
#   'winner': {'score': None, 'users': []},
#   'slateType': 114,
#   'gameCount': 1,
#   'siteSlateId': '30947',
#   'start': '2019-10-30T00:07:00.000Z',
#   'sport': 2,
#   'prizePool': 25000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 5945,
#   'entryFee': 5,
#   'name': 'MLB Showdown $25K Chin Music [Single Entry] (WAS vs HOU)',
#   'siteContestId': '79431640',
#   '_slateId': '5db8d51abf921925e83db47e',
#   'entryCount': 5946,
#   'rgPrizePool': 2780.6399999999994,
#   'rgPrizeWinnerCount': 143,
#   'complete': True,
#   'prizes': [{'cash': 2000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1500,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 1000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 700,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'value': 700},
#    {'cash': 500,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 350,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 250,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'value': 250},
#    {'cash': 200,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 25,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 70,
#     'maxFinish': 35,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'value': 70},
#    {'cash': 50,
#     'maxFinish': 45,
#     'minFinish': 36,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 35,
#     'maxFinish': 70,
#     'minFinish': 46,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'value': 35},
#    {'cash': 25,
#     'maxFinish': 100,
#     'minFinish': 71,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 150,
#     'minFinish': 101,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 250,
#     'minFinish': 151,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 12,
#     'maxFinish': 400,
#     'minFinish': 251,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'value': 12},
#    {'cash': 10,
#     'maxFinish': 625,
#     'minFinish': 401,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 9,
#     'maxFinish': 950,
#     'minFinish': 626,
#     'tierPayoutDescriptions': {'Cash': '$9.00'},
#     'value': 9},
#    {'cash': 8,
#     'maxFinish': 1450,
#     'minFinish': 951,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8}]},
#  {'_id': '5db9bcd3b448e42d9a2768b5',
#   'winner': {'score': None, 'users': []},
#   'slateType': 114,
#   'gameCount': 1,
#   'siteSlateId': '30947',
#   'start': '2019-10-30T00:07:00.000Z',
#   'sport': 2,
#   'prizePool': 20000,
#   'maxEntriesPerUser': 47,
#   'maxEntries': 1568,
#   'entryFee': 15,
#   'name': 'MLB $20K Game 6 Extravaganza [$5K to 1st] (WAS vs HOU)',
#   'siteContestId': '79564708',
#   '_slateId': '5db8d51abf921925e83db47e',
#   'entryCount': 1569,
#   'rgPrizePool': 2030,
#   'rgPrizeWinnerCount': 43,
#   'complete': True,
#   'prizes': [{'cash': 5000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'value': 5000},
#    {'cash': 2000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 750,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'value': 750},
#    {'cash': 500,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 7,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 8,
#     'minFinish': 8,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 12,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 75,
#     'maxFinish': 16,
#     'minFinish': 13,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'value': 75},
#    {'cash': 60,
#     'maxFinish': 20,
#     'minFinish': 17,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 26,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 45,
#     'maxFinish': 41,
#     'minFinish': 27,
#     'tierPayoutDescriptions': {'Cash': '$45.00'},
#     'value': 45},
#    {'cash': 40,
#     'maxFinish': 66,
#     'minFinish': 42,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 35,
#     'maxFinish': 106,
#     'minFinish': 67,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'value': 35},
#    {'cash': 30,
#     'maxFinish': 173,
#     'minFinish': 107,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 310,
#     'minFinish': 174,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25}]},
#  {'_id': '5db9bcd5a7ccf22d8e254881',
#   'winner': {'score': None, 'users': []},
#   'slateType': 114,
#   'gameCount': 1,
#   'siteSlateId': '30947',
#   'start': '2019-10-30T00:07:00.000Z',
#   'sport': 2,
#   'prizePool': 12000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 14268,
#   'entryFee': 1,
#   'name': 'MLB Showdown $12K mini-MAX [150 Max Entry] (WAS vs HOU)',
#   'siteContestId': '79562195',
#   '_slateId': '5db8d51abf921925e83db47e',
#   'entryCount': 14269,
#   'rgPrizePool': 701.1200000000001,
#   'rgPrizeWinnerCount': 280,
#   'complete': True,
#   'prizes': [{'cash': 1500,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'value': 1500},
#    {'cash': 700,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'value': 700},
#    {'cash': 500,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 250,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'value': 250},
#    {'cash': 150,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 50,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 30,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 30,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 10,
#     'maxFinish': 50,
#     'minFinish': 31,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10},
#    {'cash': 8,
#     'maxFinish': 80,
#     'minFinish': 51,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'value': 8},
#    {'cash': 6,
#     'maxFinish': 150,
#     'minFinish': 81,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'value': 6},
#    {'cash': 5,
#     'maxFinish': 285,
#     'minFinish': 151,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'value': 5},
#    {'cash': 4,
#     'maxFinish': 585,
#     'minFinish': 286,
#     'tierPayoutDescriptions': {'Cash': '$4.00'},
#     'value': 4},
#    {'cash': 3,
#     'maxFinish': 1235,
#     'minFinish': 586,
#     'tierPayoutDescriptions': {'Cash': '$3.00'},
#     'value': 3},
#    {'cash': 2,
#     'maxFinish': 3025,
#     'minFinish': 1236,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'value': 2}]},
#  {'_id': '5db8e23c5b291d25ee93a2f9',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 2,
#   'siteSlateId': '30964',
#   'start': '2019-10-30T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 100000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 11764,
#   'entryFee': 10,
#   'name': 'NBA $100K Pull Up Jumper [$20K to 1st] (Night)',
#   'siteContestId': '79499876',
#   '_slateId': '5db8e23b5b291d25ee93a2b5',
#   'entryCount': 11765,
#   'rgPrizePool': 17829.14,
#   'rgPrizeWinnerCount': 766,
#   'complete': True,
#   'prizes': [{'cash': 20000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'value': 20000},
#    {'cash': 10000,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'value': 10000},
#    {'cash': 5000,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'value': 5000},
#    {'cash': 3000,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'value': 3000},
#    {'cash': 2000,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'value': 2000},
#    {'cash': 1000,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 500,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 200,
#     'maxFinish': 20,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 100,
#     'maxFinish': 25,
#     'minFinish': 21,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 75,
#     'maxFinish': 35,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'value': 75},
#    {'cash': 60,
#     'maxFinish': 50,
#     'minFinish': 36,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 90,
#     'minFinish': 51,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 175,
#     'minFinish': 91,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 345,
#     'minFinish': 176,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 695,
#     'minFinish': 346,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 1310,
#     'minFinish': 696,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 2710,
#     'minFinish': 1311,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15}]},
#  {'_id': '5db8e2505b291d25ee93d131',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 2,
#   'siteSlateId': '30964',
#   'start': '2019-10-30T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 2000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 459,
#   'entryFee': 5,
#   'name': 'NBA Single Entry $5 Double Up (Night)',
#   'siteContestId': '79485692',
#   '_slateId': '5db8e23b5b291d25ee93a2b5',
#   'entryCount': 460,
#   'rgPrizePool': 350,
#   'rgPrizeWinnerCount': 35,
#   'complete': False,
#   'prizes': [{'cash': 10,
#     'maxFinish': 200,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'value': 10}]},
#  {'_id': '5db8e2515b291d25ee93d3a4',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 2,
#   'siteSlateId': '30964',
#   'start': '2019-10-30T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 2000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 91,
#   'entryFee': 25,
#   'name': 'NBA Single Entry $25 Double Up (Night)',
#   'siteContestId': '79485691',
#   '_slateId': '5db8e23b5b291d25ee93a2b5',
#   'entryCount': 92,
#   'rgPrizePool': 650,
#   'rgPrizeWinnerCount': 13,
#   'complete': False,
#   'prizes': [{'cash': 50,
#     'maxFinish': 40,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50}]},
#  {'_id': '5db9bc3a08f5472d9c209509',
#   'winner': {'score': None, 'users': []},
#   'slateType': 70,
#   'gameCount': 2,
#   'siteSlateId': '30964',
#   'start': '2019-10-30T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 5,
#   'maxEntries': 176,
#   'entryFee': 33,
#   'name': 'NBA $5K Triple Threat (Night)',
#   'siteContestId': '79485686',
#   '_slateId': '5db8e23b5b291d25ee93a2b5',
#   'entryCount': 177,
#   'rgPrizePool': 882,
#   'rgPrizeWinnerCount': 11,
#   'complete': True,
#   'prizes': [{'cash': 600,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'value': 600},
#    {'cash': 500,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 400,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'value': 400},
#    {'cash': 300,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'value': 300},
#    {'cash': 260,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$260.00'},
#     'value': 260},
#    {'cash': 200,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 9,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 100,
#     'maxFinish': 14,
#     'minFinish': 10,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 80,
#     'maxFinish': 24,
#     'minFinish': 15,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80},
#    {'cash': 66,
#     'maxFinish': 39,
#     'minFinish': 25,
#     'tierPayoutDescriptions': {'Cash': '$66.00'},
#     'value': 66}]},
#  ...]

# %%
arr = get_data_rg('10/01/2018', '12/31/2018')

# %%
df = df_prep(arr)
df['month'] = df['start'].apply(lambda x:x.strftime('%B'))

# %%
end = pd.to_datetime('01/01/2019')

df = df.loc[df['start'] < end]

# %%
import seaborn as sns

df['month'] = df['start'].apply(lambda x:x.strftime('%B'))
fig = plt.figure(figsize=(18,10))
sns.countplot(x="month", hue="sport", data=df).set_title('End of 2018, tournaments played')
plt.show()
plt.savefig('2018_end.png')

# %%
with open('RG_{}_{}.json'.format(sdate, edate), 'a') as outfile:
        #    json.dump(data, outfile)

# %%
df = rg_df('RG_10-24-19_11-07-19.json')

# %%
#df[df.gameCount.isna() == True]

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                                    name sport  gameCount  \
# 57                  $40k thu nhl breakaway ($8k to 1st)   NHL      10.00
# 58         $5k thu nhl big $2 double up (top 1,250 win)   NHL      10.00
# 59                       $12k thu nhl goal ($2k to 1st)   NHL      10.00
# 60                 $5k thu nhl wrister (20 entries max)   NHL      10.00
# 61                                 $10k thu nhl monster   NHL      10.00
# 62                          $8k thu nba piggy bank shot   NBA       3.00
# 63                 $16k thu nba dribbler (single entry)   NBA       3.00
# 64             $400k thu nba clutch shot ($100k to 1st)   NBA       3.00
# 65               $30k thu nba fadeaway ($0.25 to enter)   NBA       3.00
# 66            $10k thu nba pick n roll (20 entries max)   NBA       3.00
# 67    $12k thu nba big $2 quintuple up - 5x (top 1,2...   NBA       3.00
# 68                 $12k thu nba windmill (single entry)   NBA       3.00
# 69        $20k thu nba big $2 double up (top 5,000 win)   NBA       3.00
# 70                     $10k thu nba dime (single entry)   NBA       3.00
# 71                     $8k thu nba swat (3 entries max)   NBA       3.00
# 72                    $15k thu nba block (single entry)   NBA       3.00
# 73                     $125k thu nba slam ($25k to 1st)   NBA       3.00
# 74        $12k thu nba big $5 double up (top 1,200 win)   NBA       3.00
# 75                     $60k thu nba layup ($10k to 1st)   NBA       3.00
# 76    $11k thu nba epe shot (experienced players exc...   NBA       3.00
# 77    $6k thu nba big $5 quintuple up - 5x (top 240 ...   NBA       3.00
# 78                   $12k thu nba assist (single entry)   NBA       3.00
# 79                  $6k thu nba swingman (single entry)   NBA       3.00
# 80                  $5k thu nba rebound (5 entries max)   NBA       3.00
# 81                $15k thu nba rainmaker (single entry)   NBA       3.00
# 82                  $150k thu nba monster ($50k to 1st)   NBA       3.00
# 83                   $100k thu nba baller ($50k to 1st)   NBA       3.00
# 84          $5k thu nba big $25 double up (top 100 win)   NBA       3.00
# 85                  $12k thu nba and one (single entry)   NBA       3.00
# 86                     $9k thu nba swish (single entry)   NBA       3.00
# ...                                                 ...   ...        ...
# 2354                $33k thu nhl breakaway ($5k to 1st)   NHL      11.00
# 2355                               $10k thu nhl monster   NHL      11.00
# 2356                     $10k thu nhl goal ($2k to 1st)   NHL      11.00
# 2378                        $7k thu nba piggy bank shot   NBA       4.00
# 2379        $25k thu nba fadeaway (only $0.25 to enter)   NBA       4.00
# 2380          $20k thu nba pick n roll (25 entries max)   NBA       4.00
# 2381               $14k thu nba dribbler (single entry)   NBA       4.00
# 2382                   $60k thu nba layup ($10k to 1st)   NBA       4.00
# 2383           $400k thu nba clutch shot ($100k to 1st)   NBA       4.00
# 2384      $16k thu nba big $5 double up (top 1,600 win)   NBA       4.00
# 2385      $26k thu nba big $2 double up (top 6,500 win)   NBA       4.00
# 2386                  $10k thu nba swat (3 entries max)   NBA       4.00
# 2387      $6k thu nba epe shot (no experienced players)   NBA       4.00
# 2388  $12k thu nba big $2 quintuple up - 5x (top 1,2...   NBA       4.00
# 2389  $8k thu nba big $5 quintuple up - 5x (top 320 ...   NBA       4.00
# 2390                   $125k thu nba slam ($25k to 1st)   NBA       4.00
# 2391                   $12k thu nba dime (single entry)   NBA       4.00
# 2392                  $16k thu nba block (single entry)   NBA       4.00
# 2393                 $14k thu nba assist (single entry)   NBA       4.00
# 2394                $12k thu nba charge (3 entries max)   NBA       4.00
# 2395                $20k thu nba and one (single entry)   NBA       4.00
# 2396                                  $15k thu nba dunk   NBA       4.00
# 2397                $7k thu nba rebound (5 entries max)   NBA       4.00
# 2398                 $100k thu nba baller ($50k to 1st)   NBA       4.00
# 2399                $150k thu nba monster ($50k to 1st)   NBA       4.00
# 2400               $9k thu nba swingman (3 entries max)   NBA       4.00
# 2401                  $15k thu nba swish (single entry)   NBA       4.00
# 2402               $25k thu nba windmill (single entry)   NBA       4.00
# 2403                $12k thu nba putback (single entry)   NBA       4.00
# 2404               $33k thu nba rainmaker ($10k to 1st)   NBA       4.00
#
#      dayofweek               start  prizePool  entryFee  maxEntriesPerUser  \
# 57    Thursday 2019-10-24 23:00:00   40000.00      4.44                nan
# 58    Thursday 2019-10-24 23:00:00    4999.00      2.00                nan
# 59    Thursday 2019-10-24 23:00:00   12000.00     33.00                nan
# 60    Thursday 2019-10-24 23:00:00    5000.00      2.00                nan
# 61    Thursday 2019-10-24 23:00:00   10000.00    333.00                nan
# 62    Thursday 2019-10-24 23:00:00    7997.00      0.05                nan
# 63    Thursday 2019-10-24 23:00:00   16000.00      1.00                nan
# 64    Thursday 2019-10-24 23:00:00  399999.00      4.44                nan
# 65    Thursday 2019-10-24 23:00:00   30002.00      0.25                nan
# 66    Thursday 2019-10-24 23:00:00   10000.00      2.22                nan
# 67    Thursday 2019-10-24 23:00:00   12000.00      2.00                nan
# 68    Thursday 2019-10-24 23:00:00   12000.00    100.00                nan
# 69    Thursday 2019-10-24 23:00:00   20000.00      2.00                nan
# 70    Thursday 2019-10-24 23:00:00   10000.00     10.00                nan
# 71    Thursday 2019-10-24 23:00:00    8000.00      1.00                nan
# 72    Thursday 2019-10-24 23:00:00   15000.00      2.00                nan
# 73    Thursday 2019-10-24 23:00:00  125000.00     33.00                nan
# 74    Thursday 2019-10-24 23:00:00   12000.00      5.00                nan
# 75    Thursday 2019-10-24 23:00:00   60000.00      9.00                nan
# 76    Thursday 2019-10-24 23:00:00   11000.00      3.00                nan
# 77    Thursday 2019-10-24 23:00:00    6000.00      5.00                nan
# 78    Thursday 2019-10-24 23:00:00   12000.00      5.00                nan
# 79    Thursday 2019-10-24 23:00:00    6000.00     15.00                nan
# 80    Thursday 2019-10-24 23:00:00    5000.00     12.00                nan
# 81    Thursday 2019-10-24 23:00:00   15000.00    535.00                nan
# 82    Thursday 2019-10-24 23:00:00  150000.00    444.00                nan
# 83    Thursday 2019-10-24 23:00:00  100000.00   1650.00                nan
# 84    Thursday 2019-10-24 23:00:00    5000.00     25.00                nan
# 85    Thursday 2019-10-24 23:00:00   12000.00     25.00                nan
# 86    Thursday 2019-10-24 23:00:00    9000.00     50.00                nan
# ...        ...                 ...        ...       ...                ...
# 2354    Friday 2019-11-08 00:00:00   33000.00      4.44                nan
# 2355    Friday 2019-11-08 00:00:00   10000.00    333.00                nan
# 2356    Friday 2019-11-08 00:00:00   10000.00     33.00                nan
# 2378    Friday 2019-11-08 01:00:00    7001.00      0.05                nan
# 2379    Friday 2019-11-08 01:00:00   25004.00      0.25                nan
# 2380    Friday 2019-11-08 01:00:00   20000.00      2.22                nan
# 2381    Friday 2019-11-08 01:00:00   14000.00      1.00                nan
# 2382    Friday 2019-11-08 01:00:00   60000.00      9.00                nan
# 2383    Friday 2019-11-08 01:00:00  400000.00      5.55                nan
# 2384    Friday 2019-11-08 01:00:00   16000.00      5.00                nan
# 2385    Friday 2019-11-08 01:00:00   26000.00      2.00                nan
# 2386    Friday 2019-11-08 01:00:00   10000.00      1.00                nan
# 2387    Friday 2019-11-08 01:00:00    6000.00      3.00                nan
# 2388    Friday 2019-11-08 01:00:00   12000.00      2.00                nan
# 2389    Friday 2019-11-08 01:00:00    8000.00      5.00                nan
# 2390    Friday 2019-11-08 01:00:00  125000.00     44.00                nan
# 2391    Friday 2019-11-08 01:00:00   12000.00     10.00                nan
# 2392    Friday 2019-11-08 01:00:00   16000.00      2.00                nan
# 2393    Friday 2019-11-08 01:00:00   14000.00      5.00                nan
# 2394    Friday 2019-11-08 01:00:00   12000.00     65.00                nan
# 2395    Friday 2019-11-08 01:00:00   20000.00     25.00                nan
# 2396    Friday 2019-11-08 01:00:00   15000.00    100.00                nan
# 2397    Friday 2019-11-08 01:00:00    7000.00     10.00                nan
# 2398    Friday 2019-11-08 01:00:00  100000.00   1650.00                nan
# 2399    Friday 2019-11-08 01:00:00  150000.00    555.00                nan
# 2400    Friday 2019-11-08 01:00:00    9000.00     15.00                nan
# 2401    Friday 2019-11-08 01:00:00   15000.00     50.00                nan
# 2402    Friday 2019-11-08 01:00:00   25000.00    100.00                nan
# 2403    Friday 2019-11-08 01:00:00   12000.00    222.00                nan
# 2404    Friday 2019-11-08 01:00:00   33000.00    535.00                nan
#
#       maxEntries  entryCount
# 57           nan       10725
# 58           nan        2873
# 59           nan         427
# 60           nan        2743
# 61           nan          33
# 62           nan      177979
# 63           nan       19047
# 64           nan      107250
# 65           nan      141187
# 66           nan        5362
# 67           nan        6735
# 68           nan         136
# 69           nan       11494
# 70           nan        1176
# 71           nan        9523
# 72           nan        8928
# 73           nan        4456
# 74           nan        2758
# 75           nan        7936
# 76           nan        3234
# 77           nan        1379
# 78           nan        2857
# 79           nan         470
# 80           nan         490
# 81           nan          30
# 82           nan         375
# 83           nan          63
# 84           nan         207
# 85           nan         564
# 86           nan         204
# ...          ...         ...
# 2354         nan        8848
# 2355         nan          33
# 2356         nan         356
# 2378         nan      167664
# 2379         nan      119760
# 2380         nan       10725
# 2381         nan       16666
# 2382         nan        7936
# 2383         nan       85556
# 2384         nan        3621
# 2385         nan       13923
# 2386         nan       11904
# 2387         nan        2222
# 2388         nan        6896
# 2389         nan        1839
# 2390         nan        3191
# 2391         nan        1411
# 2392         nan        9523
# 2393         nan        3333
# 2394         nan         209
# 2395         nan         941
# 2396         nan         160
# 2397         nan         823
# 2398         nan          65
# 2399         nan         300
# 2400         nan         689
# 2401         nan         340
# 2402         nan         284
# 2403         nan          60
# 2404         nan          65
#
# [361 rows x 10 columns]

# %%
nfl = df[df.sport == 'NFL']
nhl = df[df.sport == 'NHL']
golf = df[df.sport == 'GOLF']
mlb = df[df.sport == 'MLB']
nba = df[df.sport == 'NBA']

# %%
labels = np.unique(df.sport.values).tolist()
labels
# Out:
# ['GOLF', 'MLB', 'NBA', 'NFL', 'NHL']

# %%
gc = df.groupby("sport")['gameCount'].sum()
gc
# Out:
# sport
# GOLF     26.00
# MLB      63.00
# NBA    5495.00
# NFL    5751.00
# NHL    1071.00
# Name: gameCount, dtype: float64

# %%
pp = df.groupby("sport")['prizePool'].sum()

# %%
labels = np.unique(df.sport.values).tolist()
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen', 'lightblue']
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=labels, values=[gc[0], gc[1], gc[2], gc[3], gc[4]], name='Overall Tournaments Played'),
              1, 1)
fig.add_trace(go.Pie(labels=labels, values=[pp[0], pp[1], pp[2], pp[3], pp[4]], name='Overall prizepool'),
              1, 2)

fig.update_traces(hole=.4, hoverinfo='label+name+value', marker=dict(colors=colors, line=dict(color='#000000', width=2)))

fig.update_layout(
        title={
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
    title_text='2019 Sport types comparsion',
    annotations=[dict(text='Tourney count', x=0.14, y=0.5, font_size=20, showarrow=False),
                 dict(text='Prizes sum', x=0.84, y=0.5, font_size=20, showarrow=False)])
fig.show()
# Out:
# <div>
#
#
#             <div id="1126dec7-6736-4300-ab4e-0613ca1e2163" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1126dec7-6736-4300-ab4e-0613ca1e2163")) {
#                     Plotly.newPlot(
#                         '1126dec7-6736-4300-ab4e-0613ca1e2163',
#                         [{"domain": {"x": [0.0, 0.45], "y": [0.0, 1.0]}, "hole": 0.4, "hoverinfo": "label+name+value", "labels": ["GOLF", "MLB", "NBA", "NFL", "NHL"], "marker": {"colors": ["gold", "mediumturquoise", "darkorange", "lightgreen", "lightblue"], "line": {"color": "#000000", "width": 2}}, "name": "Overall Tournaments Played", "type": "pie", "values": [26.0, 63.0, 5495.0, 5751.0, 1071.0]}, {"domain": {"x": [0.55, 1.0], "y": [0.0, 1.0]}, "hole": 0.4, "hoverinfo": "label+name+value", "labels": ["GOLF", "MLB", "NBA", "NFL", "NHL"], "marker": {"colors": ["gold", "mediumturquoise", "darkorange", "lightgreen", "lightblue"], "line": {"color": "#000000", "width": 2}}, "name": "Overall prizepool", "type": "pie", "values": [557100.0, 1404850.0, 29715933.0, 52336902.09999998, 2649290.0]}],
#                         {"annotations": [{"font": {"size": 20}, "showarrow": false, "text": "Tourney count", "x": 0.14, "y": 0.5}, {"font": {"size": 20}, "showarrow": false, "text": "Prizes sum", "x": 0.84, "y": 0.5}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "sc ...

# %%
nfl.head(5)
# Out:
#                                                  name sport  gameCount  \
# 95  nfl showdown $80k bootleg [$20k to 1st] (was v...   NFL       1.00
# 96  nfl showdown $95k luxury box [$50k to 1st] (wa...   NFL       1.00
# 97  nfl showdown $150k deep threat [$50k to 1st] (...   NFL       1.00
# 98  nfl $200k thursday night showdown [$50k to 1st...   NFL       1.00
# 99  nfl showdown $60k play-action [20 entry max] (...   NFL       1.00
#
#    dayofweek               start  prizePool  entryFee  maxEntriesPerUser  \
# 95    Friday 2019-10-25 00:20:00   80000.00     33.00              84.00
# 96    Friday 2019-10-25 00:20:00   95000.00   1500.00               2.00
# 97    Friday 2019-10-25 00:20:00  150000.00    180.00              27.00
# 98    Friday 2019-10-25 00:20:00  200000.00     10.00             150.00
# 99    Friday 2019-10-25 00:20:00   60000.00      3.00              20.00
#
#     maxEntries  entryCount
# 95     2827.00        2828
# 96       67.00          68
# 97      925.00         926
# 98    23529.00       23530
# 99    23781.00       23782

# %%
nfl.describe()
# Out:
#        prizePool  entryFee  maxEntriesPerUser  maxEntries  entryCount
# count      82.00     82.00              82.00       82.00       82.00
# mean    63221.41    239.47              19.51    13685.78    13686.78
# std    234061.65    671.99              38.48    37547.38    37547.38
# min      5000.00      0.10               1.00       10.00       11.00
# 25%      6000.00      5.00               1.00      111.00      112.00
# 50%     12000.00     25.00               3.00      689.00      690.00
# 75%     25000.00    100.00              20.00     4562.25     4563.25
# max   1500000.00   5375.00             150.00   176470.00   176471.00

# %%
nfl.prizePool.sum()
# Out:
# 5184155.55

# %%
doubleups = nfl['name'].str.contains('Double Up').sum()
print ('Double ups количество в неделю: {} \nПроцент от общего числа турниров: {:.0f}%'.format(doubleups, doubleups/nfl.name.count()*100))
# Out:
# Double ups количество в неделю: 25
# Процент от общего числа турниров: 30%

# %%
nhl.head(5)
# Out:
#                                     name sport  gameCount dayofweek  \
# 2       nhl $8k forecheck [20 entry max]   NHL          7    Monday
# 3  nhl $5.2k power forward [2 entry max]   NHL          7    Monday
# 4      nhl $15.6k sin bin [single entry]   NHL          7    Monday
# 5       nhl $40k blue line [$10k to 1st]   NHL          7    Monday
# 6               nhl $6.85k crease master   NHL          7    Monday
#
#                 start  prizePool  entryFee  maxEntriesPerUser  maxEntries  \
# 2 2019-10-14 17:00:00    8000.00      4.00                 20        2378
# 3 2019-10-14 17:00:00    5200.00     88.00                  2          67
# 4 2019-10-14 17:00:00   15600.00   1500.00                  1          11
# 5 2019-10-14 17:00:00   40000.00    222.00                  6         200
# 6 2019-10-14 17:00:00    6850.00    691.00                  1          11
#
#    entryCount
# 2        2379
# 3          68
# 4          12
# 5         201
# 6          12

# %%
nhl.describe()
# Out:
#        prizePool  entryFee  maxEntriesPerUser  maxEntries  entryCount
# count      19.00     19.00              19.00       19.00       19.00
# mean    19127.37    199.66              24.32     2197.47     2192.89
# std     29067.91    411.19              45.69     3430.90     3432.72
# min      5000.00      0.50               1.00       10.00       11.00
# 25%      5000.00      5.00               1.00      169.00      170.00
# 50%      8000.00     20.00               3.00      583.00      584.00
# 75%     14810.00    104.50              20.00     1703.50     1704.50
# max    100000.00   1500.00             150.00    11890.00    11891.00

# %%
nhl.prizePool.sum()
# Out:
# 140650.0

# %%
doubleups = nhl['name'].str.contains('Double Up').sum()
print ('Double ups количество в неделю: {} \nПроцент от общего числа турниров: {:.0f}%'.format(doubleups, doubleups/nhl.name.count()*100))
# Out:
# Double ups количество в неделю: 1
# Процент от общего числа турниров: 5%

# %%
print (json_data[17]['entryCount'], '\n', json_normalize(json_data[17]['prizes']))
# Out:
# 11891
#      cash  maxFinish  minFinish tierPayoutDescriptions.Cash  value
# 0   1000          1          1                   $1,000.00   1000
# 1    350          2          2                     $350.00    350
# 2    200          3          3                     $200.00    200
# 3    100          4          4                     $100.00    100
# 4     50          5          5                      $50.00     50
# 5     30          7          6                      $30.00     30
# 6     20         10          8                      $20.00     20
# 7     15         13         11                      $15.00     15
# 8     10         18         14                      $10.00     10
# 9      8         28         19                       $8.00      8
# 10     6         48         29                       $6.00      6
# 11     5         73         49                       $5.00      5
# 12     4        103         74                       $4.00      4
# 13     3        183        104                       $3.00      3
# 14     2        383        184                       $2.00      2
# 15     1       2383        384                       $1.00      1

# %%
json_normalize(json_data[19]['prizes'])
# Out:
#      cash  maxFinish  minFinish tierPayoutDescriptions.Cash  value
# 0   25000          1          1                  $25,000.00  25000
# 1   10000          2          2                  $10,000.00  10000
# 2    5000          3          3                   $5,000.00   5000
# 3    3500          4          4                   $3,500.00   3500
# 4    2500          5          5                   $2,500.00   2500
# 5    2000          7          6                   $2,000.00   2000
# 6    1500         10          8                   $1,500.00   1500
# 7    1000         13         11                   $1,000.00   1000
# 8     700         20         14                     $700.00    700
# 9     600         29         21                     $600.00    600
# 10    500         51         30                     $500.00    500
# 11    400        104         52                     $400.00    400

# %%
rg_2018 = get_data_rg('01/01/2018', '12/31/2018')

# %%
with open('rg_2018.json', 'w', encoding='utf-8') as f:
    json.dump(rg_2018, f, ensure_ascii=False, indent=4)

# %%
# !ls
# Out:
# nflgame.ipynb  simple_eda.ipynb     sportsref_download.csv  Untitled.ipynb
# rg_2018.json   simple_eda-v2.ipynb  testdata.json

# %%
rg_2018
# Out:
# [{'_id': '5b45e8a262fa9e4e0fe5184e',
#   'rgPrizePool': 28071,
#   'rgPrizeWinnerCount': 197,
#   'entryCount': 2811,
#   'prizePool': 80000,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22721',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 4,
#   'maxEntriesPerUser': None,
#   'entryFee': 33,
#   'name': '$80K Tue NHL SUPER Goal ($20K to 1st)',
#   'siteContestId': '215048594',
#   '_slateId': '5b45e8a062fa9e4e0fe509ef',
#   'complete': True,
#   'prizes': [{'maxFinish': 2795, 'minFinish': 1694, 'cash': 0},
#    {'maxFinish': 560, 'minFinish': 560, 'cash': 20},
#    {'maxFinish': 559, 'minFinish': 446, 'cash': 60},
#    {'maxFinish': 314, 'minFinish': 314, 'cash': 64},
#    {'maxFinish': 313, 'minFinish': 225, 'cash': 70},
#    {'maxFinish': 163, 'minFinish': 163, 'cash': 77.5},
#    {'maxFinish': 160, 'minFinish': 99, 'cash': 80},
#    {'maxFinish': 65, 'minFinish': 37, 'cash': 100},
#    {'maxFinish': 35, 'minFinish': 35, 'cash': 125},
#    {'maxFinish': 34, 'minFinish': 24, 'cash': 150},
#    {'maxFinish': 19, 'minFinish': 13, 'cash': 200},
#    {'maxFinish': 12, 'minFinish': 12, 'cash': 300},
#    {'maxFinish': 8, 'minFinish': 7, 'cash': 500},
#    {'maxFinish': 6, 'minFinish': 6, 'cash': 750},
#    {'maxFinish': 5, 'minFinish': 5, 'cash': 1000},
#    {'maxFinish': 4, 'minFinish': 4, 'cash': 2000},
#    {'maxFinish': 3, 'minFinish': 3, 'cash': 4000},
#    {'maxFinish': 2, 'minFinish': 2, 'cash': 10000},
#    {'maxFinish': 1, 'minFinish': 1, 'cash': 20000}]},
#  {'_id': '5b45e8a262fa9e4e0fe518a8',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 5,
#   'name': '$10K Tue NBA BIG $5 Quintuple Up - 5X (Top 400 Win)',
#   'siteContestId': '215073740',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518da',
#   'rgPrizePool': 2421,
#   'rgPrizeWinnerCount': 61,
#   'entryCount': 934,
#   'prizePool': 5570,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22721',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 4,
#   'maxEntriesPerUser': None,
#   'entryFee': 7,
#   'name': '$5,555 Tue NHL Crossbar ($1,000 to 1st)',
#   'siteContestId': '215048738',
#   '_slateId': '5b45e8a062fa9e4e0fe509ef',
#   'complete': True,
#   'prizes': [{'maxFinish': 933, 'minFinish': 565, 'cash': 0},
#    {'maxFinish': 170, 'minFinish': 170, 'cash': 7.5},
#    {'maxFinish': 168, 'minFinish': 83, 'cash': 15},
#    {'maxFinish': 60, 'minFinish': 60, 'cash': 22},
#    {'maxFinish': 32, 'minFinish': 26, 'cash': 33},
#    {'maxFinish': 21, 'minFinish': 17, 'cash': 44},
#    {'maxFinish': 13, 'minFinish': 10, 'cash': 55},
#    {'maxFinish': 9, 'minFinish': 9, 'cash': 66},
#    {'maxFinish': 7, 'minFinish': 7, 'cash': 71.5},
#    {'maxFinish': 6, 'minFinish': 6, 'cash': 100},
#    {'maxFinish': 4, 'minFinish': 4, 'cash': 137.5},
#    {'maxFinish': 2, 'minFinish': 2, 'cash': 372.5},
#    {'maxFinish': 1, 'minFinish': 1, 'cash': 1000}]},
#  {'_id': '5b45e8a262fa9e4e0fe5189a',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 55,
#   'name': '$200K Tue NBA Slam ($50K to 1st)',
#   'siteContestId': '215073571',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518a9',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 25,
#   'name': '$18K Tue NBA And One (Single Entry)',
#   'siteContestId': '215073561',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe5184d',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 2,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 1,
#   'name': '$20K Tue NBA Dribbler (Single Entry)',
#   'siteContestId': '215073494',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': [{'maxFinish': 16105, 'minFinish': 16105, 'cash': 0}]},
#  {'_id': '5b45e8a262fa9e4e0fe51893',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 2,
#   'name': '$15K Tue NBA Block (Single Entry)',
#   'siteContestId': '215073499',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518ca',
#   'rgPrizePool': 13121,
#   'rgPrizeWinnerCount': 557,
#   'entryCount': 10416,
#   'prizePool': 35001,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22721',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 4,
#   'maxEntriesPerUser': None,
#   'entryFee': 4,
#   'name': '$35K Tue NHL Breakaway ($5K to 1st)',
#   'siteContestId': '215048718',
#   '_slateId': '5b45e8a062fa9e4e0fe509ef',
#   'complete': True,
#   'prizes': [{'maxFinish': 10417, 'minFinish': 4620, 'cash': 0},
#    {'maxFinish': 1928, 'minFinish': 1928, 'cash': 4.8},
#    {'maxFinish': 1926, 'minFinish': 1653, 'cash': 8},
#    {'maxFinish': 797, 'minFinish': 797, 'cash': 8.33},
#    {'maxFinish': 796, 'minFinish': 419, 'cash': 10},
#    {'maxFinish': 400, 'minFinish': 390, 'cash': 12},
#    {'maxFinish': 195, 'minFinish': 121, 'cash': 15},
#    {'maxFinish': 93, 'minFinish': 93, 'cash': 17.86},
#    {'maxFinish': 91, 'minFinish': 86, 'cash': 20},
#    {'maxFinish': 70, 'minFinish': 70, 'cash': 25},
#    {'maxFinish': 68, 'minFinish': 67, 'cash': 30},
#    {'maxFinish': 40, 'minFinish': 40, 'cash': 38.67},
#    {'maxFinish': 39, 'minFinish': 38, 'cash': 60},
#    {'maxFinish': 32, 'minFinish': 29, 'cash': 80},
#    {'maxFinish': 25, 'minFinish': 23, 'cash': 100},
#    {'maxFinish': 20, 'minFinish': 16, 'cash': 120},
#    {'maxFinish': 14, 'minFinish': 13, 'cash': 150},
#    {'maxFinish': 12, 'minFinish': 12, 'cash': 200},
#    {'maxFinish': 9, 'minFinish': 9, 'cash': 250},
#    {'maxFinish': 7, 'minFinish': 7, 'cash': 350},
#    {'maxFinish': 6, 'minFinish': 6, 'cash': 500},
#    {'maxFinish': 5, 'minFinish': 5, 'cash': 750},
#    {'maxFinish': 4, 'minFinish': 4, 'cash': 1000},
#    {'maxFinish': 3, 'minFinish': 3, 'cash': 2000},
#    {'maxFinish': 2, 'minFinish': 2, 'cash': 3000},
#    {'maxFinish': 1, 'minFinish': 1, 'cash': 5000}]},
#  {'_id': '5b45e8a262fa9e4e0fe51a40',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 370,
#   'name': '$200K Tue NBA Monster ($50K to 1st)',
#   'siteContestId': '215073633',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe5188e',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 5,
#   'name': '$22K Tue NBA BIG $5 Double Up (Top 2,200 Win)',
#   'siteContestId': '215073713',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51898',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 11,
#   'name': '$5500 Tue NBA BIG $11 Double Up (Top 250 Win)',
#   'siteContestId': '215073721',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51956',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 1,
#   'name': '$10K Tue NBA Swat (3 Entries Max)',
#   'siteContestId': '215073496',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51988',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 5,
#   'name': '$13K Tue NBA Assist (Single Entry)',
#   'siteContestId': '215073520',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51891',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 0.25,
#   'name': '$25K Tue NBA Fadeaway (Only $0.25 to Enter)',
#   'siteContestId': '215073468',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51892',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 2,
#   'name': '$35K Tue NBA BIG $2 Double Up (Top 8,750 Win)',
#   'siteContestId': '215073702',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe5188d',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 4.44,
#   'name': '$444K Tue NBA Clutch Shot ($100K to 1st)',
#   'siteContestId': '215077025',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51897',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 2,
#   'name': '$16K Tue NBA BIG $2 Quintuple Up - 5X (Top 1,600 Win)',
#   'siteContestId': '215073738',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518b5',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 7,
#   'name': '$60K Tue NBA Layup ($15K to 1st)',
#   'siteContestId': '215073524',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51b05',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 12,
#   'name': '$6K Tue NBA Rebound (5 Entries Max)',
#   'siteContestId': '215073542',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a362fa9e4e0fe51c77',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 10,
#   'name': '$12K Tue NBA Dime (Single Entry)',
#   'siteContestId': '215073534',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a362fa9e4e0fe51d4a',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 50,
#   'name': '$10K Tue NBA Swish (Single Entry)',
#   'siteContestId': '215073580',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a362fa9e4e0fe51fd3',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 15,
#   'name': '$9K Tue NBA Swingman (3 Entries Max)',
#   'siteContestId': '215073550',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a462fa9e4e0fe5222f',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 25,
#   'name': '$7K Tue NBA BIG $25 Double Up (Top 140 Win)',
#   'siteContestId': '215073723',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a562fa9e4e0fe527bd',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 65,
#   'name': '$10K Tue NBA Charge (3 Entries Max)',
#   'siteContestId': '215073601',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a762fa9e4e0fe53440',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 100,
#   'name': '$12K Tue NBA Windmill (Single Entry)',
#   'siteContestId': '215073605',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a762fa9e4e0fe5375e',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 222,
#   'name': '$22K Tue NBA Putback (Single Entry)',
#   'siteContestId': '215073620',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a962fa9e4e0fe543fe',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 100,
#   'name': '$9K Tue NBA Dunk ($9K Guaranteed)',
#   'siteContestId': '215073614',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8ad62fa9e4e0fe55928',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 1590,
#   'name': '$100K Tue NBA Baller ($25K to 1st)',
#   'siteContestId': '215073644',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8c462fa9e4e0fe5ded8',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 530,
#   'name': '$22K Tue NBA Rainmaker (Single Entry)',
#   'siteContestId': '215073641',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5ae4aa4bd69dcc3dfd7b371f',
#   'rgPrizePool': 5091.54,
#   'rgPrizeWinnerCount': 182,
#   'entryCount': 2941,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 30000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 2941,
#   'entryFee': 12,
#   'name': 'NBA $30K Pick + Roll [Single Entry]',
#   'siteContestId': '52068200',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'showtime_2nd'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'mjblackwell916'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 36,
#     'maxFinish': 50,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 51,
#     'maxFinish': 70,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 71,
#     'maxFinish': 100,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 101,
#     'maxFinish': 150,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 151,
#     'maxFinish': 225,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 226,
#     'maxFinish': 325,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 326,
#     'maxFinish': 485,
#     'cash': 20},
#    {'value': 18,
#     'tierPayoutDescriptions': {'Cash': '$18.00'},
#     'minFinish': 486,
#     'maxFinish': 710,
#     'cash': 18}]},
#  {'_id': '5ae4aa7dc074cf3dffdb9680',
#   'rgPrizePool': 9159.99,
#   'rgPrizeWinnerCount': 91,
#   'entryCount': 883,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 25000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 883,
#   'entryFee': 33,
#   'name': 'NBA $25K Bank Shot [3 Entry Max]',
#   'siteContestId': '52068201',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'pumakehr'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 2500},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1000},
#    {'value': 800,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 800},
#    {'value': 600,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 600},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 46,
#     'maxFinish': 70,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 71,
#     'maxFinish': 100,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 101,
#     'maxFinish': 135,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 136,
#     'maxFinish': 207,
#     'cash': 50}]},
#  {'_id': '5ae4aac5dd71203dfcde4ebb',
#   'rgPrizePool': 9165.72,
#   'rgPrizeWinnerCount': 100,
#   'entryCount': 1166,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 40000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1166,
#   'entryFee': 40,
#   'name': 'NBA $40K Mid Range Jumper [Single Entry]',
#   'siteContestId': '52068202',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'rmsamano'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'gould-lox'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'mjblackwell916'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 4000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 2500},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 4,
#     'maxFinish': 5,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 6,
#     'maxFinish': 8,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 9,
#     'maxFinish': 11,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 12,
#     'maxFinish': 15,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 21,
#     'maxFinish': 26,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 27,
#     'maxFinish': 41,
#     'cash': 150},
#    {'value': 120,
#     'tierPayoutDescriptions': {'Cash': '$120.00'},
#     'minFinish': 42,
#     'maxFinish': 71,
#     'cash': 120},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 72,
#     'maxFinish': 111,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 112,
#     'maxFinish': 176,
#     'cash': 80},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 177,
#     'maxFinish': 291,
#     'cash': 60}]},
#  {'_id': '5ae4ab0a5689223dfaa83ea8',
#   'rgPrizePool': 35000,
#   'rgPrizeWinnerCount': 7,
#   'entryCount': 67,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 67000,
#   'maxEntriesPerUser': 2,
#   'maxEntries': 67,
#   'entryFee': 1060,
#   'name': 'NBA $67K All-Star [2 Entry Max]',
#   'siteContestId': '52068203',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'petteytheft89',
#      'rgUserId': '43822',
#      'siteEntryName': 'petteytheft89'}],
#    'score': 342.5},
#   'complete': True,
#   'prizes': [{'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 20000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 10000},
#    {'value': 6000,
#     'tierPayoutDescriptions': {'Cash': '$6,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 6000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 5000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 3000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 2500},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 9,
#     'maxFinish': 15,
#     'cash': 2000}]},
#  {'_id': '5ae4ab0c5689223dfaa83eec',
#   'rgPrizePool': 1262.5,
#   'rgPrizeWinnerCount': 27,
#   'entryCount': 490,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 490,
#   'entryFee': 12,
#   'name': 'NBA $5K Pick + Roll [Single Entry]',
#   'siteContestId': '52088103',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'mjblackwell916'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'evil4378'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 750},
#    {'value': 425,
#     'tierPayoutDescriptions': {'Cash': '$425.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 425},
#    {'value': 275,
#     'tierPayoutDescriptions': {'Cash': '$275.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 275},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 75},
#    {'value': 65,
#     'tierPayoutDescriptions': {'Cash': '$65.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 65},
#    {'value': 55,
#     'tierPayoutDescriptions': {'Cash': '$55.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 55},
#    {'value': 45,
#     'tierPayoutDescriptions': {'Cash': '$45.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 45},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 26,
#     'maxFinish': 30,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 41,
#     'maxFinish': 60,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 61,
#     'maxFinish': 90,
#     'cash': 25}]},
#  {'_id': '5ae4aba05689223dfaa97265',
#   'rgPrizePool': 2875,
#   'rgPrizeWinnerCount': 95,
#   'entryCount': 882,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 26,
#   'maxEntries': 882,
#   'entryFee': 8,
#   'name': 'NBA $6K Excellent 8’s [$1K to 1st]',
#   'siteContestId': '52096905',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'awesemo',
#      'rgUserId': '54849',
#      'siteEntryName': 'Awesemo'}],
#    'score': 347.5},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 500},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 250},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 80},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 70},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 26,
#     'maxFinish': 41,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 42,
#     'maxFinish': 61,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 62,
#     'maxFinish': 85,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 86,
#     'maxFinish': 115,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 116,
#     'maxFinish': 225,
#     'cash': 12}]},
#  {'_id': '5ae4aba2c074cf3dffdfacfc',
#   'rgPrizePool': 20030.07999999999,
#   'rgPrizeWinnerCount': 2884,
#   'entryCount': 51525,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 130000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 51525,
#   'entryFee': 3,
#   'name': 'NBA $130K Sharpshooter [20 Entry Max]',
#   'siteContestId': '52068205',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'realitydreams4'}],
#    'score': 381},
#   'complete': True,
#   'prizes': [{'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 5000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 350},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 41,
#     'maxFinish': 50,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 51,
#     'maxFinish': 75,
#     'cash': 80},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 76,
#     'maxFinish': 100,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 101,
#     'maxFinish': 125,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 126,
#     'maxFinish': 150,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 151,
#     'maxFinish': 200,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 201,
#     'maxFinish': 250,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 251,
#     'maxFinish': 300,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 301,
#     'maxFinish': 400,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 401,
#     'maxFinish': 500,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 501,
#     'maxFinish': 750,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 751,
#     'maxFinish': 1250,
#     'cash': 10},
#    {'value': 9,
#     'tierPayoutDescriptions': {'Cash': '$9.00'},
#     'minFinish': 1251,
#     'maxFinish': 2000,
#     'cash': 9},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 2001,
#     'maxFinish': 3000,
#     'cash': 8},
#    {'value': 7,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'minFinish': 3001,
#     'maxFinish': 5000,
#     'cash': 7},
#    {'value': 6,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'minFinish': 5001,
#     'maxFinish': 8500,
#     'cash': 6},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 8501,
#     'maxFinish': 14900,
#     'cash': 5}]},
#  {'_id': '5ae4ac01f69c5a3e00bb4b66',
#   'rgPrizePool': 66125.31999999998,
#   'rgPrizeWinnerCount': 482,
#   'entryCount': 5300,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 150000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 5300,
#   'entryFee': 33,
#   'name': 'NBA $150K Triple Threat',
#   'siteContestId': '52068206',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'djchurney',
#      'rgUserId': '261961',
#      'siteEntryName': 'daquestion4u'}],
#    'score': 366.25},
#   'complete': True,
#   'prizes': [{'value': 15000,
#     'tierPayoutDescriptions': {'Cash': '$15,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 15000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 10000},
#    {'value': 7000,
#     'tierPayoutDescriptions': {'Cash': '$7,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 7000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 5000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 36,
#     'maxFinish': 60,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 61,
#     'maxFinish': 100,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 101,
#     'maxFinish': 150,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 151,
#     'maxFinish': 250,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 251,
#     'maxFinish': 450,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 451,
#     'maxFinish': 775,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 776,
#     'maxFinish': 1365,
#     'cash': 50}]},
#  {'_id': '5ae4ac69d69dcc3dfd82efcb',
#   'rgPrizePool': 71650,
#   'rgPrizeWinnerCount': 65,
#   'entryCount': 700,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 350000,
#   'maxEntriesPerUser': 21,
#   'maxEntries': 700,
#   'entryFee': 555,
#   'name': 'NBA $350K Alley Oop [$100K to 1st]',
#   'siteContestId': '52068207',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'cheddabisque'}],
#    'score': 355.5},
#   'complete': True,
#   'prizes': [{'value': 100000,
#     'tierPayoutDescriptions': {'Cash': '$100,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 100000},
#    {'value': 40000,
#     'tierPayoutDescriptions': {'Cash': '$40,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 40000},
#    {'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 20000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 10000},
#    {'value': 7000,
#     'tierPayoutDescriptions': {'Cash': '$7,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 7000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 5000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 11,
#     'maxFinish': 17,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 18,
#     'maxFinish': 27,
#     'cash': 1500},
#    {'value': 1200,
#     'tierPayoutDescriptions': {'Cash': '$1,200.00'},
#     'minFinish': 28,
#     'maxFinish': 47,
#     'cash': 1200},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 48,
#     'maxFinish': 97,
#     'cash': 1000},
#    {'value': 850,
#     'tierPayoutDescriptions': {'Cash': '$850.00'},
#     'minFinish': 98,
#     'maxFinish': 157,
#     'cash': 850}]},
#  {'_id': '5ae4af18d69dcc3dfd8b42d5',
#   'rgPrizePool': 1420.6799999999998,
#   'rgPrizeWinnerCount': 93,
#   'entryCount': 1189,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1189,
#   'entryFee': 5,
#   'name': 'NBA $5K High Five [Single Entry]',
#   'siteContestId': '52082316',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'pbgkid12',
#      'rgUserId': '11784',
#      'siteEntryName': 'pbgkid12'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'hondarider622'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'bigpuzz'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 30},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 46,
#     'maxFinish': 80,
#     'cash': 15},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 81,
#     'maxFinish': 155,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 156,
#     'maxFinish': 315,
#     'cash': 8}]},
#  {'_id': '5ae4b1a7c074cf3dffef9896',
#   'rgPrizePool': 39756.63000000001,
#   'rgPrizeWinnerCount': 895,
#   'entryCount': 9411,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 80000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 9411,
#   'entryFee': 10,
#   'name': 'NBA $80K New Year’s Toast [$10K to 1st]',
#   'siteContestId': '52086823',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'ThatStunna',
#      'rgUserId': '154155',
#      'siteEntryName': 'ThatStunna'}],
#    'score': 381.25},
#   'complete': True,
#   'prizes': [{'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 10000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 5000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 2500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 7,
#     'maxFinish': 7,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 8,
#     'maxFinish': 9,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 10,
#     'maxFinish': 14,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 15,
#     'maxFinish': 20,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 21,
#     'maxFinish': 35,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 36,
#     'maxFinish': 65,
#     'cash': 80},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 66,
#     'maxFinish': 115,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 116,
#     'maxFinish': 190,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 191,
#     'maxFinish': 290,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 291,
#     'maxFinish': 540,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 541,
#     'maxFinish': 940,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 941,
#     'maxFinish': 1540,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 1541,
#     'maxFinish': 2420,
#     'cash': 15}]},
#  {'_id': '5ae4b6670f94ac3e01472192',
#   'rgPrizePool': 6600,
#   'rgPrizeWinnerCount': 33,
#   'entryCount': 111,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 111,
#   'entryFee': 100,
#   'name': 'NBA $100 Double Up',
#   'siteContestId': '52063138',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 1,
#     'maxFinish': 50,
#     'cash': 200}]},
#  {'_id': '5ae4b69cdd71203dfc087fe3',
#   'rgPrizePool': 16130,
#   'rgPrizeWinnerCount': 1613,
#   'entryCount': 3448,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 15000,
#   'maxEntriesPerUser': 103,
#   'maxEntries': 3448,
#   'entryFee': 5,
#   'name': 'NBA $5 Double Up',
#   'siteContestId': '52063139',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 1,
#     'maxFinish': 1500,
#     'cash': 10}]},
#  {'_id': '5ae4b6d9f69c5a3e00d96c20',
#   'rgPrizePool': 5940,
#   'rgPrizeWinnerCount': 594,
#   'entryCount': 2298,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 68,
#   'maxEntries': 2298,
#   'entryFee': 5,
#   'name': 'NBA $5 Double Up',
#   'siteContestId': '52063140',
#   '_slateId': '5aff6348a6b8b14c55464511',
# ...
#   'maxEntries': 9908,
#   'entryFee': 3,
#   'name': 'NBA $25K Sharpshooter [20 Entry Max]',
#   'siteContestId': '52087896',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'dodgetrain'}],
#    'score': 384.5},
#   'complete': True,
#   'prizes': [{'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 3000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 75},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 31,
#     'maxFinish': 50,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 51,
#     'maxFinish': 75,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 76,
#     'maxFinish': 100,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 101,
#     'maxFinish': 150,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 151,
#     'maxFinish': 250,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 251,
#     'maxFinish': 450,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 451,
#     'maxFinish': 800,
#     'cash': 8},
#    {'value': 6,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'minFinish': 801,
#     'maxFinish': 1450,
#     'cash': 6},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 1451,
#     'maxFinish': 2420,
#     'cash': 5}]},
#  {'_id': '5ae4c86e0f94ac3e01786eb4',
#   'rgPrizePool': 20800,
#   'rgPrizeWinnerCount': 62,
#   'entryCount': 555,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 75000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 555,
#   'entryFee': 150,
#   'name': 'NBA $75K Posterizer [3 Entry Max]',
#   'siteContestId': '52068199',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'NYMicky'}],
#    'score': 347.25},
#   'complete': True,
#   'prizes': [{'value': 8000,
#     'tierPayoutDescriptions': {'Cash': '$8,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 8000},
#    {'value': 6000,
#     'tierPayoutDescriptions': {'Cash': '$6,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 6000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 5000},
#    {'value': 3500,
#     'tierPayoutDescriptions': {'Cash': '$3,500.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 3500},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 2500},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 7,
#     'maxFinish': 7,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 8,
#     'maxFinish': 10,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 350},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 46,
#     'maxFinish': 80,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 81,
#     'maxFinish': 149,
#     'cash': 250}]},
#  {'_id': '5ae4b54078af173dfe8f0212',
#   'rgPrizePool': 762.7899999999997,
#   'rgPrizeWinnerCount': 299,
#   'entryCount': 11890,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17049',
#   'start': '2018-01-02T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 11890,
#   'entryFee': 1,
#   'name': 'NBA $10K And-One (Night)',
#   'siteContestId': '52062035',
#   '_slateId': '5ae4b53e78af173dfe8efb88',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'ARTLAW'}],
#    'score': 339.25},
#   'complete': True,
#   'prizes': [{'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 4,
#     'maxFinish': 5,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 6,
#     'maxFinish': 7,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 8,
#     'maxFinish': 10,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 30},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 26,
#     'maxFinish': 40,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 41,
#     'maxFinish': 65,
#     'cash': 15},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 66,
#     'maxFinish': 110,
#     'cash': 10},
#    {'value': 7.5,
#     'tierPayoutDescriptions': {'Cash': '$7.50'},
#     'minFinish': 111,
#     'maxFinish': 200,
#     'cash': 7.5},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 201,
#     'maxFinish': 325,
#     'cash': 5},
#    {'value': 3,
#     'tierPayoutDescriptions': {'Cash': '$3.00'},
#     'minFinish': 326,
#     'maxFinish': 525,
#     'cash': 3},
#    {'value': 2.5,
#     'tierPayoutDescriptions': {'Cash': '$2.50'},
#     'minFinish': 526,
#     'maxFinish': 950,
#     'cash': 2.5},
#    {'value': 2,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'minFinish': 951,
#     'maxFinish': 1705,
#     'cash': 2},
#    {'value': 1.5,
#     'tierPayoutDescriptions': {'Cash': '$1.50'},
#     'minFinish': 1706,
#     'maxFinish': 3100,
#     'cash': 1.5}]},
#  {'_id': '5ae4bb240f94ac3e0154972c',
#   'rgPrizePool': 954.34,
#   'rgPrizeWinnerCount': 56,
#   'entryCount': 882,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17049',
#   'start': '2018-01-02T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 26,
#   'maxEntries': 882,
#   'entryFee': 8,
#   'name': 'NBA $6K Excellent 8’s [$1K to 1st] (Night)',
#   'siteContestId': '52099655',
#   '_slateId': '5ae4b53e78af173dfe8efb88',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'douglasWJ'}],
#    'score': 331.25},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 500},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 250},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 80},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 70},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 26,
#     'maxFinish': 41,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 42,
#     'maxFinish': 61,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 62,
#     'maxFinish': 85,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 86,
#     'maxFinish': 115,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 116,
#     'maxFinish': 225,
#     'cash': 12}]},
#  {'_id': '5ae4c7bac074cf3dff2c58fe',
#   'rgPrizePool': 2256.7000000000007,
#   'rgPrizeWinnerCount': 25,
#   'entryCount': 282,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17049',
#   'start': '2018-01-02T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 8000,
#   'maxEntriesPerUser': 8,
#   'maxEntries': 282,
#   'entryFee': 33,
#   'name': 'NBA $8K Triple Threat (Night)',
#   'siteContestId': '52083296',
#   '_slateId': '5ae4b53e78af173dfe8efb88',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'Boder24'}],
#    'score': 329.25},
#   'complete': True,
#   'prizes': [{'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1000},
#    {'value': 600,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 600},
#    {'value': 450,
#     'tierPayoutDescriptions': {'Cash': '$450.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 450},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 5,
#     'maxFinish': 6,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 26,
#     'maxFinish': 40,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 41,
#     'maxFinish': 60,
#     'cash': 50}]},
#  {'_id': '5ae4c8340f94ac3e0177f6f7',
#   'rgPrizePool': 21303.160000000018,
#   'rgPrizeWinnerCount': 1003,
#   'entryCount': 18382,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17049',
#   'start': '2018-01-02T01:00:00.000Z',
#   'sport': 3,
#   'prizePool': 125000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 18382,
#   'entryFee': 8,
#   'name': 'NBA $125K Late Night Snack [$20K to 1st] (Night)',
#   'siteContestId': '52083298',
#   '_slateId': '5ae4b53e78af173dfe8efb88',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'GreyPoupon'}],
#    'score': 331.75},
#   'complete': True,
#   'prizes': [{'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 20000},
#    {'value': 7500,
#     'tierPayoutDescriptions': {'Cash': '$7,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 7500},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 5000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 2000},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 9,
#     'maxFinish': 11,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 12,
#     'maxFinish': 15,
#     'cash': 350},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 16,
#     'maxFinish': 19,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 20,
#     'maxFinish': 25,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 36,
#     'maxFinish': 50,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 51,
#     'maxFinish': 70,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 71,
#     'maxFinish': 100,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 101,
#     'maxFinish': 150,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 151,
#     'maxFinish': 250,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 251,
#     'maxFinish': 500,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 501,
#     'maxFinish': 900,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 901,
#     'maxFinish': 1560,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 1561,
#     'maxFinish': 2560,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 2561,
#     'maxFinish': 4460,
#     'cash': 12}]}]

# %%
rg_20182 = get_data_rg('01/02/2018', '12/31/2018')

# %%
rg_20182
# Out:
# [{'_id': '5ae4aa4c5689223dfaa52f9a',
#   'rgPrizePool': 1820,
#   'rgPrizeWinnerCount': 91,
#   'entryCount': 574,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 574,
#   'entryFee': 10,
#   'name': 'NBA Single Entry $10 Double Up',
#   'siteContestId': '52118200',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 1,
#     'maxFinish': 250,
#     'cash': 20}]},
#  {'_id': '5ae4aac2c074cf3dffdc9ca0',
#   'rgPrizePool': 2300,
#   'rgPrizeWinnerCount': 23,
#   'entryCount': 345,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 8000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 345,
#   'entryFee': 27,
#   'name': 'NBA $8K Fast Break [Single Entry]',
#   'siteContestId': '52100702',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'tede26'}],
#    'score': 292.5},
#   'complete': True,
#   'prizes': [{'value': 1250,
#     'tierPayoutDescriptions': {'Cash': '$1,250.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1250},
#    {'value': 700,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 700},
#    {'value': 475,
#     'tierPayoutDescriptions': {'Cash': '$475.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 475},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 350},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 41,
#     'maxFinish': 70,
#     'cash': 50}]},
#  {'_id': '5ae4ab4e95356d3dfbda61d5',
#   'rgPrizePool': 1684.17,
#   'rgPrizeWinnerCount': 136,
#   'entryCount': 2378,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 2378,
#   'entryFee': 5,
#   'name': 'NBA $10K High Five [Single Entry]',
#   'siteContestId': '52100704',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'illuminaughty'}],
#    'score': 300.25},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 31,
#     'maxFinish': 50,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 51,
#     'maxFinish': 75,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 76,
#     'maxFinish': 100,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 101,
#     'maxFinish': 125,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 126,
#     'maxFinish': 200,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 201,
#     'maxFinish': 330,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 331,
#     'maxFinish': 580,
#     'cash': 8}]},
#  {'_id': '5ae4acc695356d3dfbe01c76',
#   'rgPrizePool': 2500,
#   'rgPrizeWinnerCount': 5,
#   'entryCount': 22,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 22,
#   'entryFee': 250,
#   'name': 'NBA $250 Double Up',
#   'siteContestId': '52118208',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 1,
#     'maxFinish': 10,
#     'cash': 500}]},
#  {'_id': '5ae4aeb10f94ac3e012d4445',
#   'rgPrizePool': 4538.460000000001,
#   'rgPrizeWinnerCount': 509,
#   'entryCount': 6936,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 17500,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 6936,
#   'entryFee': 3,
#   'name': 'NHL $17.5K Sniper [10X The FPP’s!]',
#   'siteContestId': '52090915',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'Mongoose09'}],
#    'score': 58.9},
#   'complete': True,
#   'prizes': [{'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1000},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 350},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 41,
#     'maxFinish': 55,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 56,
#     'maxFinish': 75,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 76,
#     'maxFinish': 100,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 101,
#     'maxFinish': 175,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 176,
#     'maxFinish': 325,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 326,
#     'maxFinish': 575,
#     'cash': 8},
#    {'value': 6,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'minFinish': 576,
#     'maxFinish': 1050,
#     'cash': 6},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 1051,
#     'maxFinish': 1750,
#     'cash': 5}]},
#  {'_id': '5ae4afd0f69c5a3e00c5cabe',
#   'rgPrizePool': 6960,
#   'rgPrizeWinnerCount': 696,
#   'entryCount': 3448,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 15000,
#   'maxEntriesPerUser': 103,
#   'maxEntries': 3448,
#   'entryFee': 5,
#   'name': 'NBA $5 Double Up',
#   'siteContestId': '52101018',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 1,
#     'maxFinish': 1500,
#     'cash': 10}]},
#  {'_id': '5ae4b0240f94ac3e01323aa3',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 99,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 8266.66,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 113,
#   'entryFee': 86,
#   'name': 'NBA $200K King of San Antonio Qualifier #24',
#   'siteContestId': '52102319',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 8267,
#     'tierPayoutDescriptions': {'Ticket': 'NBA $200K King of San Antonio Round 1 Ticket'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 0}]},
#  {'_id': '5ae4b021f69c5a3e00c6f832',
#   'rgPrizePool': 6600,
#   'rgPrizeWinnerCount': 660,
#   'entryCount': 3448,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 15000,
#   'maxEntriesPerUser': 103,
#   'maxEntries': 3448,
#   'entryFee': 5,
#   'name': 'NBA $5 Double Up',
#   'siteContestId': '52101019',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 1,
#     'maxFinish': 1500,
#     'cash': 10}]},
#  {'_id': '5ae4b07cd69dcc3dfd9087e8',
#   'rgPrizePool': 4980,
#   'rgPrizeWinnerCount': 249,
#   'entryCount': 1149,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 34,
#   'maxEntries': 1149,
#   'entryFee': 10,
#   'name': 'NBA $10 Double Up',
#   'siteContestId': '52101020',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 1,
#     'maxFinish': 500,
#     'cash': 20}]},
#  {'_id': '5ae4b10895356d3dfbf0f459',
#   'rgPrizePool': 7000,
#   'rgPrizeWinnerCount': 35,
#   'entryCount': 144,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 13000,
#   'maxEntriesPerUser': 4,
#   'maxEntries': 144,
#   'entryFee': 100,
#   'name': 'NBA $100 Double Up',
#   'siteContestId': '52101021',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 1,
#     'maxFinish': 65,
#     'cash': 200}]},
#  {'_id': '5ae4b154c074cf3dffeeb8ff',
#   'rgPrizePool': 13350,
#   'rgPrizeWinnerCount': 267,
#   'entryCount': 1357,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 30000,
#   'maxEntriesPerUser': 41,
#   'maxEntries': 1379,
#   'entryFee': 25,
#   'name': 'NBA GIANT $25 Double Up',
#   'siteContestId': '52101022',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 1,
#     'maxFinish': 600,
#     'cash': 50}]},
#  {'_id': '5ae4b1a8f69c5a3e00cb3240',
#   'rgPrizePool': 4400,
#   'rgPrizeWinnerCount': 44,
#   'entryCount': 181,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 8000,
#   'maxEntriesPerUser': 5,
#   'maxEntries': 181,
#   'entryFee': 50,
#   'name': 'NBA $50 Double Up',
#   'siteContestId': '52101023',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 1,
#     'maxFinish': 80,
#     'cash': 100}]},
#  {'_id': '5ae4b1e1d69dcc3dfd94e813',
#   'rgPrizePool': 3500,
#   'rgPrizeWinnerCount': 7,
#   'entryCount': 35,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 8000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 35,
#   'entryFee': 250,
#   'name': 'NBA $250 Double Up',
#   'siteContestId': '52101024',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 1,
#     'maxFinish': 16,
#     'cash': 500}]},
#  {'_id': '5ae4b24ac074cf3dfff19ee9',
#   'rgPrizePool': 19000,
#   'rgPrizeWinnerCount': 4,
#   'entryCount': 65,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 19000,
#   'maxEntriesPerUser': 2,
#   'maxEntries': 67,
#   'entryFee': 333,
#   'name': 'NHL $400K Fantasy Hockey World Championship Qualifier #9',
#   'siteContestId': '52064525',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': 'PetrGibbons',
#      'rgUserId': '89470',
#      'siteEntryName': 'PetrGibbons'}],
#    'score': 44},
#   'complete': True,
#   'prizes': [{'value': 17500,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00',
#      'Ticket': 'NHL $400K FHWC Contest Ticket,NHL $400K FHWC Experience Ticket (1)'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1000},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 3,
#     'maxFinish': 6,
#     'cash': 500}]},
#  {'_id': '5ae4b24d5689223dfabdec77',
#   'rgPrizePool': 2096,
#   'rgPrizeWinnerCount': 524,
#   'entryCount': 3448,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 3448,
#   'entryFee': 2,
#   'name': 'NBA $2 Double Up',
#   'siteContestId': '52101025',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 4,
#     'tierPayoutDescriptions': {'Cash': '$4.00'},
#     'minFinish': 1,
#     'maxFinish': 1500,
#     'cash': 4}]},
#  {'_id': '5ae4b2990f94ac3e013b3669',
#   'rgPrizePool': 3270,
#   'rgPrizeWinnerCount': 327,
#   'entryCount': 2298,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 2298,
#   'entryFee': 5,
#   'name': 'NBA Single Entry $5 Double Up',
#   'siteContestId': '52101026',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 1,
#     'maxFinish': 1000,
#     'cash': 10}]},
#  {'_id': '5ae4b2d35689223dfabe6517',
#   'rgPrizePool': 12000,
#   'rgPrizeWinnerCount': 240,
#   'entryCount': 1609,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 35000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1609,
#   'entryFee': 25,
#   'name': 'NBA Single Entry $25 Double Up',
#   'siteContestId': '52101027',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 1,
#     'maxFinish': 700,
#     'cash': 50}]},
#  {'_id': '5ae4b2d65689223dfabe75c2',
#   'rgPrizePool': 1470.91,
#   'rgPrizeWinnerCount': 135,
#   'entryCount': 2378,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 2378,
#   'entryFee': 3,
#   'name': 'NHL $6K Sniper [10X The FPP’s!]',
#   'siteContestId': '52120627',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'khogan3131'}],
#    'score': 54.4},
#   'complete': True,
#   'prizes': [{'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 31,
#     'maxFinish': 50,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 51,
#     'maxFinish': 80,
#     'cash': 15},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 81,
#     'maxFinish': 140,
#     'cash': 10},
#    {'value': 7,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'minFinish': 141,
#     'maxFinish': 280,
#     'cash': 7},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 281,
#     'maxFinish': 565,
#     'cash': 5}]},
#  {'_id': '5ae4b320dd71203dfcfe7f0b',
#   'rgPrizePool': 2160,
#   'rgPrizeWinnerCount': 108,
#   'entryCount': 574,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 574,
#   'entryFee': 10,
#   'name': 'NBA Single Entry $10 Double Up',
#   'siteContestId': '52101028',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 1,
#     'maxFinish': 250,
#     'cash': 20}]},
#  {'_id': '5ae4b405f69c5a3e00d20249',
#   'rgPrizePool': 3050,
#   'rgPrizeWinnerCount': 305,
#   'entryCount': 1724,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 7500,
#   'maxEntriesPerUser': 51,
#   'maxEntries': 1724,
#   'entryFee': 5,
#   'name': 'NBA $5 Double Up',
#   'siteContestId': '52120831',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 1,
#     'maxFinish': 750,
#     'cash': 10}]},
#  {'_id': '5ae4b44995356d3dfbfb9f22',
#   'rgPrizePool': 2522.5,
#   'rgPrizeWinnerCount': 21,
#   'entryCount': 215,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 215,
#   'entryFee': 27,
#   'name': 'NBA $5K Fast Break [Single Entry]',
#   'siteContestId': '52119932',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': 'ajschul',
#      'rgUserId': '223192',
#      'siteEntryName': 'anthonys54'}],
#    'score': 286.25},
#   'complete': True,
#   'prizes': [{'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 200},
#    {'value': 175,
#     'tierPayoutDescriptions': {'Cash': '$175.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 175},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 11,
#     'maxFinish': 12,
#     'cash': 100},
#    {'value': 85,
#     'tierPayoutDescriptions': {'Cash': '$85.00'},
#     'minFinish': 13,
#     'maxFinish': 15,
#     'cash': 85},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 70},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 26,
#     'maxFinish': 34,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 35,
#     'maxFinish': 52,
#     'cash': 40}]},
#  {'_id': '5ae4b4fef69c5a3e00d44be8',
#   'rgPrizePool': 845.5,
#   'rgPrizeWinnerCount': 73,
#   'entryCount': 1189,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1189,
#   'entryFee': 5,
#   'name': 'NBA $5K High Five [Single Entry]',
#   'siteContestId': '52119934',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'Wrigley83'}],
#    'score': 310},
#   'complete': True,
#   'prizes': [{'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 30},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 46,
#     'maxFinish': 80,
#     'cash': 15},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 81,
#     'maxFinish': 155,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 156,
#     'maxFinish': 315,
#     'cash': 8}]},
#  {'_id': '5ae4b5a4f69c5a3e00d61625',
#   'rgPrizePool': 3750,
#   'rgPrizeWinnerCount': 75,
#   'entryCount': 459,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 459,
#   'entryFee': 25,
#   'name': 'NBA Single Entry $25 Double Up',
#   'siteContestId': '52121436',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 1,
#     'maxFinish': 200,
#     'cash': 50}]},
#  {'_id': '5ae4be0b95356d3dfb16385d',
#   'rgPrizePool': 1840,
#   'rgPrizeWinnerCount': 92,
#   'entryCount': 574,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 574,
#   'entryFee': 10,
#   'name': 'NBA Single Entry $10 Double Up',
#   'siteContestId': '52113863',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 1,
#     'maxFinish': 250,
#     'cash': 20}]},
#  {'_id': '5ae4be840f94ac3e015c5afc',
#   'rgPrizePool': 6100,
#   'rgPrizeWinnerCount': 17,
#   'entryCount': 100,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 13500,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 100,
#   'entryFee': 150,
#   'name': 'NHL $13.5K Glove Save',
#   'siteContestId': '52090464',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'saceto'}],
#    'score': 46.5},
#   'complete': True,
#   'prizes': [{'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 2500},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 4,
#     'maxFinish': 5,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 6,
#     'maxFinish': 7,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 8,
#     'maxFinish': 12,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 13,
#     'maxFinish': 17,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 18,
#     'maxFinish': 27,
#     'cash': 250}]},
#  {'_id': '5ae4bed2dd71203dfc1e126f',
#   'rgPrizePool': 10000,
#   'rgPrizeWinnerCount': 2,
#   'entryCount': 10,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 14200,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 10,
#   'entryFee': 1500,
#   'name': 'NHL $14.2K Sin Bin [Single Entry]',
#   'siteContestId': '52090465',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': 'freddyfar',
#      'rgUserId': '145974',
#      'siteEntryName': 'tonybalony'}],
#    'score': 39.2},
#   'complete': True,
#   'prizes': [{'value': 7500,
#     'tierPayoutDescriptions': {'Cash': '$7,500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 7500},
#    {'value': 4200,
#     'tierPayoutDescriptions': {'Cash': '$4,200.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 4200},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 2500}]},
#  {'_id': '5ae4bf0d95356d3dfb18e37f',
#   'rgPrizePool': 1770,
#   'rgPrizeWinnerCount': 177,
#   'entryCount': 1379,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1379,
#   'entryFee': 5,
#   'name': 'NBA Single Entry $5 Double Up',
#   'siteContestId': '52113866',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 1,
#     'maxFinish': 600,
#     'cash': 10}]},
#  {'_id': '5ae4bf0d78af173dfeb15980',
#   'rgPrizePool': 27887.379999999997,
#   'rgPrizeWinnerCount': 328,
#   'entryCount': 2827,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 80000,
#   'maxEntriesPerUser': 84,
#   'maxEntries': 2827,
#   'entryFee': 33,
#   'name': 'NHL $80K Line Change Special [$15K to 1st]',
#   'siteContestId': '52090466',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'ChHawks27'}],
#    'score': 55.7},
#   'complete': True,
#   'prizes': [{'value': 15000,
#     'tierPayoutDescriptions': {'Cash': '$15,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 15000},
#    {'value': 8500,
#     'tierPayoutDescriptions': {'Cash': '$8,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 8500},
#    {'value': 4500,
#     'tierPayoutDescriptions': {'Cash': '$4,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 4500},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 2500},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 350},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 36,
#     'maxFinish': 55,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 56,
#     'maxFinish': 95,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 96,
#     'maxFinish': 170,
#     'cash': 80},
#    {'value': 65,
#     'tierPayoutDescriptions': {'Cash': '$65.00'},
#     'minFinish': 171,
#     'maxFinish': 320,
#     'cash': 65},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 321,
#     'maxFinish': 655,
#     'cash': 50}]},
#  {'_id': '5ae4bf92dd71203dfc20322e',
#   'rgPrizePool': 30000,
#   'rgPrizeWinnerCount': 7,
#   'entryCount': 72,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 102000,
#   'maxEntriesPerUser': 2,
#   'maxEntries': 72,
#   'entryFee': 1500,
#   'name': 'NBA $102K Courtside Special [2 Entry Max]',
#   'siteContestId': '52100568',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'zbb123'}],
#    'score': 275.75},
#   'complete': True,
#   'prizes': [{'value': 25000,
#     'tierPayoutDescriptions': {'Cash': '$25,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 25000},
#    {'value': 15000,
#     'tierPayoutDescriptions': {'Cash': '$15,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 15000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 10000},
#    {'value': 8000,
#     'tierPayoutDescriptions': {'Cash': '$8,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 8000},
#    {'value': 6000,
#     'tierPayoutDescriptions': {'Cash': '$6,000.00'},
#     'minFinish': 5,
#     'maxFinish': 6,
#     'cash': 6000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 9,
#     'maxFinish': 11,
#     'cash': 3000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 12,
#     'maxFinish': 17,
#     'cash': 2500}]},
#  {'_id': '5ae4bf9378af173dfeb31a68',
#   'rgPrizePool': 13500,
#   'rgPrizeWinnerCount': 13,
#   'entryCount': 101,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 25000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 101,
#   'entryFee': 275,
#   'name': 'NHL $25K Stick Lift',
#   'siteContestId': '52090468',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'alainjakubowicz'}],
#    'score': 45.3},
#   'complete': True,
#   'prizes': [{'value': 6000,
#     'tierPayoutDescriptions': {'Cash': '$6,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 6000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 4000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 2500},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 1000},
#    {'value': 800,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'minFinish': 6,
#     'maxFinish': 7,
#     'cash': 800},
#    {'value': 600,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'minFinish': 8,
#     'maxFinish': 11,
#     'cash': 600},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 12,
#     'maxFinish': 23,
#     'cash': 500}]},
#  {'_id': '5ae4bff178af173dfeb53793',
#   'rgPrizePool': 2950,
#   'rgPrizeWinnerCount': 2,
#   'entryCount': 68,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 42400,
#   'maxEntriesPerUser': 2,
#   'maxEntries': 68,
#   'entryFee': 725,
#   'name': 'NBA $4M FBWC Qualifier #9',
#   'siteContestId': '52102369',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'mgoody22'}],
#    'score': 289.5},
#   'complete': True,
#   'prizes': [{'value': 38725,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00',
#      'Ticket': 'NBA $4M FBWC Contest Ticket\t,NBA $4M FBWC Experience Ticket'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 1750,
#     'tierPayoutDescriptions': {'Cash': '$1,750.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1750},
#    {'value': 1200,
#     'tierPayoutDescriptions': {'Cash': '$1,200.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1200},
#    {'value': 725,
#     'tierPayoutDescriptions': {'Cash': '$725.00'},
#     'minFinish': 4,
#     'maxFinish': 5,
#     'cash': 725}]},
#  {'_id': '5ae4bff15689223dfae0d4d3',
#   'rgPrizePool': 10682.32,
#   'rgPrizeWinnerCount': 463,
#   'entryCount': 4411,
#   'slateType': 4,
#   'gameCount': 12,
#   'siteSlateId': '17064',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 4,
#   'prizePool': 30000,
#   'maxEntriesPerUser': 132,
#   'maxEntries': 4411,
#   'entryFee': 8,
#   'name': 'NHL $30K Two-Man Advantage',
#   'siteContestId': '52090469',
#   '_slateId': '5ae4aeb00f94ac3e012d3d82',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'ChHawks27'}],
#    'score': 55.7},
#   'complete': True,
#   'prizes': [{'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 3000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1000},
#    {'value': 700,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 700},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 31,
#     'maxFinish': 45,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 46,
#     'maxFinish': 65,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 66,
#     'maxFinish': 100,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 101,
#     'maxFinish': 150,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 151,
#     'maxFinish': 225,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 226,
#     'maxFinish': 375,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 376,
#     'maxFinish': 610,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 611,
#     'maxFinish': 1085,
#     'cash': 12}]},
#  {'_id': '5ae4bff95689223dfae0e621',
#   'rgPrizePool': 1700,
#   'rgPrizeWinnerCount': 2,
#   'entryCount': 22,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 22,
#   'entryFee': 300,
#   'name': 'NBA $6K 3-Ball [Single Entry]',
#   'siteContestId': '52113869',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'MLZ29'}],
#    'score': 268},
#   'complete': True,
#   'prizes': [{'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 1100,
#     'tierPayoutDescriptions': {'Cash': '$1,100.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1100},
#    {'value': 800,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 800},
#    {'value': 600,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 600}]},
#  {'_id': '5ae4bff1f69c5a3e00f5ca01',
#   'rgPrizePool': 6800.480000000007,
#   'rgPrizeWinnerCount': 2243,
#   'entryCount': 47562,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 40000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 47562,
#   'entryFee': 1,
#   'name': 'NBA $40K And-One [20 Entry Max]',
#   'siteContestId': '52100569',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'lewisr2279'}],
#    'score': 321.5},
#   'complete': True,
#   'prizes': [{'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 2000},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1000},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 7,
#     'maxFinish': 7,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 8,
#     'maxFinish': 10,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 36,
#     'maxFinish': 45,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 46,
#     'maxFinish': 59,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 60,
#     'maxFinish': 79,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 80,
#     'maxFinish': 99,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 100,
#     'maxFinish': 149,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 150,
#     'maxFinish': 224,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 225,
#     'maxFinish': 374,
#     'cash': 8},
#    {'value': 6,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'minFinish': 375,
#     'maxFinish': 624,
#     'cash': 6},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 625,
#     'maxFinish': 1024,
#     'cash': 5},
#    {'value': 4,
#     'tierPayoutDescriptions': {'Cash': '$4.00'},
#     'minFinish': 1025,
#     'maxFinish': 1774,
#     'cash': 4},
#    {'value': 3,
#     'tierPayoutDescriptions': {'Cash': '$3.00'},
#     'minFinish': 1775,
#     'maxFinish': 3474,
#     'cash': 3},
#    {'value': 2.5,
#     'tierPayoutDescriptions': {'Cash': '$2.50'},
#     'minFinish': 3475,
#     'maxFinish': 6674,
#     'cash': 2.5},
#    {'value': 2,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'minFinish': 6675,
#     'maxFinish': 11974,
#     'cash': 2}]},
#  {'_id': '5ae4c044c074cf3dff17b8e2',
#   'rgPrizePool': 83103.5,
#   'rgPrizeWinnerCount': 787,
#   'entryCount': 6412,
#   'slateType': 3,
#   'gameCount': 5,
#   'siteSlateId': '17071',
#   'start': '2018-01-03T00:00:00.000Z',
#   'sport': 3,
#   'prizePool': 200000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 7067,
#   'entryFee': 33,
#   'name': 'NBA $200K Triple Threat',
#   'siteContestId': '52100570',
#   '_slateId': '5aff63489109304c57c2ad30',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'T3lls'}],
#    'score': 306.75},
#   'complete': True,
#   'prizes': [{'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 20000},
#    {'value': 15000,
#     'tierPayoutDescriptions': {'Cash': '$15,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 15000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 10000},
#    {'value': 7000,
#     'tierPayoutDescriptions': {'Cash': '$7,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 7000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 5000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 7,
#     'maxFinish': 7,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 8,
#     'maxFinish': 8,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
# ...
#     'minFinish': 776,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'value': 2}]},
#  {'_id': '5b80af9526ed4308d96d9a9f',
#   'rgPrizePool': 1702.46,
#   'rgPrizeWinnerCount': 83,
#   'entryCount': 1470,
#   'winner': {'score': 300.25, 'users': [{'siteEntryName': 'mosslefty'}]},
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17085',
#   'start': '2018-01-03T02:00:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 44,
#   'maxEntries': 1470,
#   'entryFee': 8,
#   'name': 'NBA $10K Excellent 8’s (Turbo)',
#   'siteContestId': '52117444',
#   '_slateId': '5b809fffe5f794085a450270',
#   'complete': True,
#   'prizes': [{'cash': 1000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 500,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 350,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 200,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 125,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'value': 125},
#    {'cash': 100,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 80,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80},
#    {'cash': 60,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 25,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 40,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 65,
#     'minFinish': 41,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 100,
#     'minFinish': 66,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 160,
#     'minFinish': 101,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 250,
#     'minFinish': 161,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 12,
#     'maxFinish': 395,
#     'minFinish': 251,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'value': 12}]},
#  {'_id': '5ae4c292dd71203dfc285ccf',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 22,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 22,
#   'entryFee': 300,
#   'name': 'NBA $6K 3-Ball [Single Entry] (Night)',
#   'siteContestId': '52117078',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'nmangskau'}],
#    'score': 262},
#   'complete': True,
#   'prizes': [{'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 1100,
#     'tierPayoutDescriptions': {'Cash': '$1,100.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1100},
#    {'value': 800,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 800},
#    {'value': 600,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 600}]},
#  {'_id': '5ae4c290d69dcc3dfdc368a1',
#   'rgPrizePool': 962.4599999999999,
#   'rgPrizeWinnerCount': 295,
#   'entryCount': 17835,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 15000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 17835,
#   'entryFee': 1,
#   'name': 'NBA $15K And-One (Night)',
#   'siteContestId': '52101778',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'jdubeast'}],
#    'score': 288.5},
#   'complete': True,
#   'prizes': [{'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 41,
#     'maxFinish': 55,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 56,
#     'maxFinish': 75,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 76,
#     'maxFinish': 115,
#     'cash': 15},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 116,
#     'maxFinish': 200,
#     'cash': 10},
#    {'value': 7,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'minFinish': 201,
#     'maxFinish': 315,
#     'cash': 7},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 316,
#     'maxFinish': 560,
#     'cash': 5},
#    {'value': 3,
#     'tierPayoutDescriptions': {'Cash': '$3.00'},
#     'minFinish': 561,
#     'maxFinish': 1050,
#     'cash': 3},
#    {'value': 2,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'minFinish': 1051,
#     'maxFinish': 2150,
#     'cash': 2},
#    {'value': 1.5,
#     'tierPayoutDescriptions': {'Cash': '$1.50'},
#     'minFinish': 2151,
#     'maxFinish': 4450,
#     'cash': 1.5}]},
#  {'_id': '5ae4c2c50f94ac3e0167c738',
#   'rgPrizePool': 1868.4599999999998,
#   'rgPrizeWinnerCount': 109,
#   'entryCount': 3567,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 12000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 3567,
#   'entryFee': 4,
#   'name': 'NBA $12K Four Point Play [20 Entry Max] (Night)',
#   'siteContestId': '52101779',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'closhardy'}],
#    'score': 281},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 700,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 700},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 36,
#     'maxFinish': 45,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 46,
#     'maxFinish': 60,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 61,
#     'maxFinish': 80,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 81,
#     'maxFinish': 115,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 116,
#     'maxFinish': 165,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 166,
#     'maxFinish': 230,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 231,
#     'maxFinish': 330,
#     'cash': 8},
#    {'value': 7,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'minFinish': 331,
#     'maxFinish': 530,
#     'cash': 7},
#    {'value': 6,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'minFinish': 531,
#     'maxFinish': 880,
#     'cash': 6}]},
#  {'_id': '5ae4c2fa0f94ac3e01686730',
#   'rgPrizePool': 2245,
#   'rgPrizeWinnerCount': 20,
#   'entryCount': 424,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 12000,
#   'maxEntriesPerUser': 12,
#   'maxEntries': 424,
#   'entryFee': 33,
#   'name': 'NBA $12K Triple Threat (Night)',
#   'siteContestId': '52117080',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'mazwa'},
#     {'rgUserName': 'Bae_Wise',
#      'rgUserId': '151886',
#      'siteEntryName': 'BeatdownBae'}],
#    'score': 271},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 6,
#     'maxFinish': 7,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 8,
#     'maxFinish': 11,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 12,
#     'maxFinish': 18,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 19,
#     'maxFinish': 30,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 31,
#     'maxFinish': 50,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 51,
#     'maxFinish': 80,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 81,
#     'maxFinish': 124,
#     'cash': 50}]},
#  {'_id': '5ae4c3500f94ac3e0169856d',
#   'rgPrizePool': 22322.139999999985,
#   'rgPrizeWinnerCount': 1302,
#   'entryCount': 24780,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 200000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 29411,
#   'entryFee': 8,
#   'name': 'NBA $200K West Coast Special 2018 Tip-Off [$30K to 1st] (Night)',
#   'siteContestId': '52117081',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'rm036'}],
#    'score': 289.5},
#   'complete': True,
#   'prizes': [{'value': 30000,
#     'tierPayoutDescriptions': {'Cash': '$30,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 30000},
#    {'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 20000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 10000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 5000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 3000},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 7,
#     'maxFinish': 7,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 8,
#     'maxFinish': 9,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 10,
#     'maxFinish': 12,
#     'cash': 350},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 13,
#     'maxFinish': 16,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 17,
#     'maxFinish': 25,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 46,
#     'maxFinish': 85,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 86,
#     'maxFinish': 135,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 136,
#     'maxFinish': 215,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 216,
#     'maxFinish': 315,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 316,
#     'maxFinish': 440,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 441,
#     'maxFinish': 690,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 691,
#     'maxFinish': 1192,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 1193,
#     'maxFinish': 1787,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 1788,
#     'maxFinish': 3292,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 3293,
#     'maxFinish': 7292,
#     'cash': 12}]}]

# %%
rg = rg_2018+rg_20182

# %%
rg
# Out:
# [{'_id': '5b45e8a262fa9e4e0fe5184e',
#   'rgPrizePool': 28071,
#   'rgPrizeWinnerCount': 197,
#   'entryCount': 2811,
#   'prizePool': 80000,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22721',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 4,
#   'maxEntriesPerUser': None,
#   'entryFee': 33,
#   'name': '$80K Tue NHL SUPER Goal ($20K to 1st)',
#   'siteContestId': '215048594',
#   '_slateId': '5b45e8a062fa9e4e0fe509ef',
#   'complete': True,
#   'prizes': [{'maxFinish': 2795, 'minFinish': 1694, 'cash': 0},
#    {'maxFinish': 560, 'minFinish': 560, 'cash': 20},
#    {'maxFinish': 559, 'minFinish': 446, 'cash': 60},
#    {'maxFinish': 314, 'minFinish': 314, 'cash': 64},
#    {'maxFinish': 313, 'minFinish': 225, 'cash': 70},
#    {'maxFinish': 163, 'minFinish': 163, 'cash': 77.5},
#    {'maxFinish': 160, 'minFinish': 99, 'cash': 80},
#    {'maxFinish': 65, 'minFinish': 37, 'cash': 100},
#    {'maxFinish': 35, 'minFinish': 35, 'cash': 125},
#    {'maxFinish': 34, 'minFinish': 24, 'cash': 150},
#    {'maxFinish': 19, 'minFinish': 13, 'cash': 200},
#    {'maxFinish': 12, 'minFinish': 12, 'cash': 300},
#    {'maxFinish': 8, 'minFinish': 7, 'cash': 500},
#    {'maxFinish': 6, 'minFinish': 6, 'cash': 750},
#    {'maxFinish': 5, 'minFinish': 5, 'cash': 1000},
#    {'maxFinish': 4, 'minFinish': 4, 'cash': 2000},
#    {'maxFinish': 3, 'minFinish': 3, 'cash': 4000},
#    {'maxFinish': 2, 'minFinish': 2, 'cash': 10000},
#    {'maxFinish': 1, 'minFinish': 1, 'cash': 20000}]},
#  {'_id': '5b45e8a262fa9e4e0fe518a8',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 5,
#   'name': '$10K Tue NBA BIG $5 Quintuple Up - 5X (Top 400 Win)',
#   'siteContestId': '215073740',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518da',
#   'rgPrizePool': 2421,
#   'rgPrizeWinnerCount': 61,
#   'entryCount': 934,
#   'prizePool': 5570,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22721',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 4,
#   'maxEntriesPerUser': None,
#   'entryFee': 7,
#   'name': '$5,555 Tue NHL Crossbar ($1,000 to 1st)',
#   'siteContestId': '215048738',
#   '_slateId': '5b45e8a062fa9e4e0fe509ef',
#   'complete': True,
#   'prizes': [{'maxFinish': 933, 'minFinish': 565, 'cash': 0},
#    {'maxFinish': 170, 'minFinish': 170, 'cash': 7.5},
#    {'maxFinish': 168, 'minFinish': 83, 'cash': 15},
#    {'maxFinish': 60, 'minFinish': 60, 'cash': 22},
#    {'maxFinish': 32, 'minFinish': 26, 'cash': 33},
#    {'maxFinish': 21, 'minFinish': 17, 'cash': 44},
#    {'maxFinish': 13, 'minFinish': 10, 'cash': 55},
#    {'maxFinish': 9, 'minFinish': 9, 'cash': 66},
#    {'maxFinish': 7, 'minFinish': 7, 'cash': 71.5},
#    {'maxFinish': 6, 'minFinish': 6, 'cash': 100},
#    {'maxFinish': 4, 'minFinish': 4, 'cash': 137.5},
#    {'maxFinish': 2, 'minFinish': 2, 'cash': 372.5},
#    {'maxFinish': 1, 'minFinish': 1, 'cash': 1000}]},
#  {'_id': '5b45e8a262fa9e4e0fe5189a',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 55,
#   'name': '$200K Tue NBA Slam ($50K to 1st)',
#   'siteContestId': '215073571',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518a9',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 25,
#   'name': '$18K Tue NBA And One (Single Entry)',
#   'siteContestId': '215073561',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe5184d',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 2,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 1,
#   'name': '$20K Tue NBA Dribbler (Single Entry)',
#   'siteContestId': '215073494',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': [{'maxFinish': 16105, 'minFinish': 16105, 'cash': 0}]},
#  {'_id': '5b45e8a262fa9e4e0fe51893',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 2,
#   'name': '$15K Tue NBA Block (Single Entry)',
#   'siteContestId': '215073499',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518ca',
#   'rgPrizePool': 13121,
#   'rgPrizeWinnerCount': 557,
#   'entryCount': 10416,
#   'prizePool': 35001,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22721',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 4,
#   'maxEntriesPerUser': None,
#   'entryFee': 4,
#   'name': '$35K Tue NHL Breakaway ($5K to 1st)',
#   'siteContestId': '215048718',
#   '_slateId': '5b45e8a062fa9e4e0fe509ef',
#   'complete': True,
#   'prizes': [{'maxFinish': 10417, 'minFinish': 4620, 'cash': 0},
#    {'maxFinish': 1928, 'minFinish': 1928, 'cash': 4.8},
#    {'maxFinish': 1926, 'minFinish': 1653, 'cash': 8},
#    {'maxFinish': 797, 'minFinish': 797, 'cash': 8.33},
#    {'maxFinish': 796, 'minFinish': 419, 'cash': 10},
#    {'maxFinish': 400, 'minFinish': 390, 'cash': 12},
#    {'maxFinish': 195, 'minFinish': 121, 'cash': 15},
#    {'maxFinish': 93, 'minFinish': 93, 'cash': 17.86},
#    {'maxFinish': 91, 'minFinish': 86, 'cash': 20},
#    {'maxFinish': 70, 'minFinish': 70, 'cash': 25},
#    {'maxFinish': 68, 'minFinish': 67, 'cash': 30},
#    {'maxFinish': 40, 'minFinish': 40, 'cash': 38.67},
#    {'maxFinish': 39, 'minFinish': 38, 'cash': 60},
#    {'maxFinish': 32, 'minFinish': 29, 'cash': 80},
#    {'maxFinish': 25, 'minFinish': 23, 'cash': 100},
#    {'maxFinish': 20, 'minFinish': 16, 'cash': 120},
#    {'maxFinish': 14, 'minFinish': 13, 'cash': 150},
#    {'maxFinish': 12, 'minFinish': 12, 'cash': 200},
#    {'maxFinish': 9, 'minFinish': 9, 'cash': 250},
#    {'maxFinish': 7, 'minFinish': 7, 'cash': 350},
#    {'maxFinish': 6, 'minFinish': 6, 'cash': 500},
#    {'maxFinish': 5, 'minFinish': 5, 'cash': 750},
#    {'maxFinish': 4, 'minFinish': 4, 'cash': 1000},
#    {'maxFinish': 3, 'minFinish': 3, 'cash': 2000},
#    {'maxFinish': 2, 'minFinish': 2, 'cash': 3000},
#    {'maxFinish': 1, 'minFinish': 1, 'cash': 5000}]},
#  {'_id': '5b45e8a262fa9e4e0fe51a40',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 370,
#   'name': '$200K Tue NBA Monster ($50K to 1st)',
#   'siteContestId': '215073633',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe5188e',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 5,
#   'name': '$22K Tue NBA BIG $5 Double Up (Top 2,200 Win)',
#   'siteContestId': '215073713',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51898',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 11,
#   'name': '$5500 Tue NBA BIG $11 Double Up (Top 250 Win)',
#   'siteContestId': '215073721',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51956',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 1,
#   'name': '$10K Tue NBA Swat (3 Entries Max)',
#   'siteContestId': '215073496',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51988',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 5,
#   'name': '$13K Tue NBA Assist (Single Entry)',
#   'siteContestId': '215073520',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51891',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 0.25,
#   'name': '$25K Tue NBA Fadeaway (Only $0.25 to Enter)',
#   'siteContestId': '215073468',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51892',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 2,
#   'name': '$35K Tue NBA BIG $2 Double Up (Top 8,750 Win)',
#   'siteContestId': '215073702',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe5188d',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 4.44,
#   'name': '$444K Tue NBA Clutch Shot ($100K to 1st)',
#   'siteContestId': '215077025',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51897',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 2,
#   'name': '$16K Tue NBA BIG $2 Quintuple Up - 5X (Top 1,600 Win)',
#   'siteContestId': '215073738',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe518b5',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 7,
#   'name': '$60K Tue NBA Layup ($15K to 1st)',
#   'siteContestId': '215073524',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a262fa9e4e0fe51b05',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 12,
#   'name': '$6K Tue NBA Rebound (5 Entries Max)',
#   'siteContestId': '215073542',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a362fa9e4e0fe51c77',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 10,
#   'name': '$12K Tue NBA Dime (Single Entry)',
#   'siteContestId': '215073534',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a362fa9e4e0fe51d4a',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 50,
#   'name': '$10K Tue NBA Swish (Single Entry)',
#   'siteContestId': '215073580',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a362fa9e4e0fe51fd3',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 15,
#   'name': '$9K Tue NBA Swingman (3 Entries Max)',
#   'siteContestId': '215073550',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a462fa9e4e0fe5222f',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 25,
#   'name': '$7K Tue NBA BIG $25 Double Up (Top 140 Win)',
#   'siteContestId': '215073723',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a562fa9e4e0fe527bd',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 65,
#   'name': '$10K Tue NBA Charge (3 Entries Max)',
#   'siteContestId': '215073601',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a762fa9e4e0fe53440',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 100,
#   'name': '$12K Tue NBA Windmill (Single Entry)',
#   'siteContestId': '215073605',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a762fa9e4e0fe5375e',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 222,
#   'name': '$22K Tue NBA Putback (Single Entry)',
#   'siteContestId': '215073620',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8a962fa9e4e0fe543fe',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 100,
#   'name': '$9K Tue NBA Dunk ($9K Guaranteed)',
#   'siteContestId': '215073614',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8ad62fa9e4e0fe55928',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 1590,
#   'name': '$100K Tue NBA Baller ($25K to 1st)',
#   'siteContestId': '215073644',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5b45e8c462fa9e4e0fe5ded8',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 0,
#   'prizePool': 0,
#   'slateType': 1,
#   'gameCount': None,
#   'siteSlateId': '22754',
#   'start': '2018-01-02T00:00:00.000Z',
#   'sport': 3,
#   'maxEntriesPerUser': None,
#   'entryFee': 530,
#   'name': '$22K Tue NBA Rainmaker (Single Entry)',
#   'siteContestId': '215073641',
#   '_slateId': '5b45e8a162fa9e4e0fe51276',
#   'complete': True,
#   'prizes': []},
#  {'_id': '5ae4aa4bd69dcc3dfd7b371f',
#   'rgPrizePool': 5091.54,
#   'rgPrizeWinnerCount': 182,
#   'entryCount': 2941,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 30000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 2941,
#   'entryFee': 12,
#   'name': 'NBA $30K Pick + Roll [Single Entry]',
#   'siteContestId': '52068200',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'showtime_2nd'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'mjblackwell916'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 36,
#     'maxFinish': 50,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 51,
#     'maxFinish': 70,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 71,
#     'maxFinish': 100,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 101,
#     'maxFinish': 150,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 151,
#     'maxFinish': 225,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 226,
#     'maxFinish': 325,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 326,
#     'maxFinish': 485,
#     'cash': 20},
#    {'value': 18,
#     'tierPayoutDescriptions': {'Cash': '$18.00'},
#     'minFinish': 486,
#     'maxFinish': 710,
#     'cash': 18}]},
#  {'_id': '5ae4aa7dc074cf3dffdb9680',
#   'rgPrizePool': 9159.99,
#   'rgPrizeWinnerCount': 91,
#   'entryCount': 883,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 25000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 883,
#   'entryFee': 33,
#   'name': 'NBA $25K Bank Shot [3 Entry Max]',
#   'siteContestId': '52068201',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'pumakehr'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 2500},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1000},
#    {'value': 800,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 800},
#    {'value': 600,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 600},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 46,
#     'maxFinish': 70,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 71,
#     'maxFinish': 100,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 101,
#     'maxFinish': 135,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 136,
#     'maxFinish': 207,
#     'cash': 50}]},
#  {'_id': '5ae4aac5dd71203dfcde4ebb',
#   'rgPrizePool': 9165.72,
#   'rgPrizeWinnerCount': 100,
#   'entryCount': 1166,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 40000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1166,
#   'entryFee': 40,
#   'name': 'NBA $40K Mid Range Jumper [Single Entry]',
#   'siteContestId': '52068202',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'rmsamano'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'gould-lox'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'mjblackwell916'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 4000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 2500},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 4,
#     'maxFinish': 5,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 6,
#     'maxFinish': 8,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 9,
#     'maxFinish': 11,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 12,
#     'maxFinish': 15,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 21,
#     'maxFinish': 26,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 27,
#     'maxFinish': 41,
#     'cash': 150},
#    {'value': 120,
#     'tierPayoutDescriptions': {'Cash': '$120.00'},
#     'minFinish': 42,
#     'maxFinish': 71,
#     'cash': 120},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 72,
#     'maxFinish': 111,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 112,
#     'maxFinish': 176,
#     'cash': 80},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 177,
#     'maxFinish': 291,
#     'cash': 60}]},
#  {'_id': '5ae4ab0a5689223dfaa83ea8',
#   'rgPrizePool': 35000,
#   'rgPrizeWinnerCount': 7,
#   'entryCount': 67,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 67000,
#   'maxEntriesPerUser': 2,
#   'maxEntries': 67,
#   'entryFee': 1060,
#   'name': 'NBA $67K All-Star [2 Entry Max]',
#   'siteContestId': '52068203',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'petteytheft89',
#      'rgUserId': '43822',
#      'siteEntryName': 'petteytheft89'}],
#    'score': 342.5},
#   'complete': True,
#   'prizes': [{'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 20000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 10000},
#    {'value': 6000,
#     'tierPayoutDescriptions': {'Cash': '$6,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 6000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 5000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 3000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 2500},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 9,
#     'maxFinish': 15,
#     'cash': 2000}]},
#  {'_id': '5ae4ab0c5689223dfaa83eec',
#   'rgPrizePool': 1262.5,
#   'rgPrizeWinnerCount': 27,
#   'entryCount': 490,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 490,
#   'entryFee': 12,
#   'name': 'NBA $5K Pick + Roll [Single Entry]',
#   'siteContestId': '52088103',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'mjblackwell916'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'evil4378'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 750},
#    {'value': 425,
#     'tierPayoutDescriptions': {'Cash': '$425.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 425},
#    {'value': 275,
#     'tierPayoutDescriptions': {'Cash': '$275.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 275},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 75},
#    {'value': 65,
#     'tierPayoutDescriptions': {'Cash': '$65.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 65},
#    {'value': 55,
#     'tierPayoutDescriptions': {'Cash': '$55.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 55},
#    {'value': 45,
#     'tierPayoutDescriptions': {'Cash': '$45.00'},
#     'minFinish': 21,
#     'maxFinish': 25,
#     'cash': 45},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 26,
#     'maxFinish': 30,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 41,
#     'maxFinish': 60,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 61,
#     'maxFinish': 90,
#     'cash': 25}]},
#  {'_id': '5ae4aba05689223dfaa97265',
#   'rgPrizePool': 2875,
#   'rgPrizeWinnerCount': 95,
#   'entryCount': 882,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 26,
#   'maxEntries': 882,
#   'entryFee': 8,
#   'name': 'NBA $6K Excellent 8’s [$1K to 1st]',
#   'siteContestId': '52096905',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'awesemo',
#      'rgUserId': '54849',
#      'siteEntryName': 'Awesemo'}],
#    'score': 347.5},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 500},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 250},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 80},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 70},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 26,
#     'maxFinish': 41,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 42,
#     'maxFinish': 61,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 62,
#     'maxFinish': 85,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 86,
#     'maxFinish': 115,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 116,
#     'maxFinish': 225,
#     'cash': 12}]},
#  {'_id': '5ae4aba2c074cf3dffdfacfc',
#   'rgPrizePool': 20030.07999999999,
#   'rgPrizeWinnerCount': 2884,
#   'entryCount': 51525,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 130000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 51525,
#   'entryFee': 3,
#   'name': 'NBA $130K Sharpshooter [20 Entry Max]',
#   'siteContestId': '52068205',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'realitydreams4'}],
#    'score': 381},
#   'complete': True,
#   'prizes': [{'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 5000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 350},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 41,
#     'maxFinish': 50,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 51,
#     'maxFinish': 75,
#     'cash': 80},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 76,
#     'maxFinish': 100,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 101,
#     'maxFinish': 125,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 126,
#     'maxFinish': 150,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 151,
#     'maxFinish': 200,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 201,
#     'maxFinish': 250,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 251,
#     'maxFinish': 300,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 301,
#     'maxFinish': 400,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 401,
#     'maxFinish': 500,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 501,
#     'maxFinish': 750,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 751,
#     'maxFinish': 1250,
#     'cash': 10},
#    {'value': 9,
#     'tierPayoutDescriptions': {'Cash': '$9.00'},
#     'minFinish': 1251,
#     'maxFinish': 2000,
#     'cash': 9},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 2001,
#     'maxFinish': 3000,
#     'cash': 8},
#    {'value': 7,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'minFinish': 3001,
#     'maxFinish': 5000,
#     'cash': 7},
#    {'value': 6,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'minFinish': 5001,
#     'maxFinish': 8500,
#     'cash': 6},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 8501,
#     'maxFinish': 14900,
#     'cash': 5}]},
#  {'_id': '5ae4ac01f69c5a3e00bb4b66',
#   'rgPrizePool': 66125.31999999998,
#   'rgPrizeWinnerCount': 482,
#   'entryCount': 5300,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 150000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 5300,
#   'entryFee': 33,
#   'name': 'NBA $150K Triple Threat',
#   'siteContestId': '52068206',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'djchurney',
#      'rgUserId': '261961',
#      'siteEntryName': 'daquestion4u'}],
#    'score': 366.25},
#   'complete': True,
#   'prizes': [{'value': 15000,
#     'tierPayoutDescriptions': {'Cash': '$15,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 15000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 10000},
#    {'value': 7000,
#     'tierPayoutDescriptions': {'Cash': '$7,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 7000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 5000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 1500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 36,
#     'maxFinish': 60,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 61,
#     'maxFinish': 100,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 101,
#     'maxFinish': 150,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 151,
#     'maxFinish': 250,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 251,
#     'maxFinish': 450,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 451,
#     'maxFinish': 775,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 776,
#     'maxFinish': 1365,
#     'cash': 50}]},
#  {'_id': '5ae4ac69d69dcc3dfd82efcb',
#   'rgPrizePool': 71650,
#   'rgPrizeWinnerCount': 65,
#   'entryCount': 700,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 350000,
#   'maxEntriesPerUser': 21,
#   'maxEntries': 700,
#   'entryFee': 555,
#   'name': 'NBA $350K Alley Oop [$100K to 1st]',
#   'siteContestId': '52068207',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'cheddabisque'}],
#    'score': 355.5},
#   'complete': True,
#   'prizes': [{'value': 100000,
#     'tierPayoutDescriptions': {'Cash': '$100,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 100000},
#    {'value': 40000,
#     'tierPayoutDescriptions': {'Cash': '$40,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 40000},
#    {'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 20000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 10000},
#    {'value': 7000,
#     'tierPayoutDescriptions': {'Cash': '$7,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 7000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 5000},
#    {'value': 4000,
#     'tierPayoutDescriptions': {'Cash': '$4,000.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 4000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 3000},
#    {'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 11,
#     'maxFinish': 17,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 18,
#     'maxFinish': 27,
#     'cash': 1500},
#    {'value': 1200,
#     'tierPayoutDescriptions': {'Cash': '$1,200.00'},
#     'minFinish': 28,
#     'maxFinish': 47,
#     'cash': 1200},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 48,
#     'maxFinish': 97,
#     'cash': 1000},
#    {'value': 850,
#     'tierPayoutDescriptions': {'Cash': '$850.00'},
#     'minFinish': 98,
#     'maxFinish': 157,
#     'cash': 850}]},
#  {'_id': '5ae4af18d69dcc3dfd8b42d5',
#   'rgPrizePool': 1420.6799999999998,
#   'rgPrizeWinnerCount': 93,
#   'entryCount': 1189,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 5000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 1189,
#   'entryFee': 5,
#   'name': 'NBA $5K High Five [Single Entry]',
#   'siteContestId': '52082316',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'pbgkid12',
#      'rgUserId': '11784',
#      'siteEntryName': 'pbgkid12'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'hondarider622'},
#     {'rgUserName': None, 'rgUserId': None, 'siteEntryName': 'bigpuzz'}],
#    'score': 355.75},
#   'complete': True,
#   'prizes': [{'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 30},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 46,
#     'maxFinish': 80,
#     'cash': 15},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 81,
#     'maxFinish': 155,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 156,
#     'maxFinish': 315,
#     'cash': 8}]},
#  {'_id': '5ae4b1a7c074cf3dffef9896',
#   'rgPrizePool': 39756.63000000001,
#   'rgPrizeWinnerCount': 895,
#   'entryCount': 9411,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 80000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 9411,
#   'entryFee': 10,
#   'name': 'NBA $80K New Year’s Toast [$10K to 1st]',
#   'siteContestId': '52086823',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [{'rgUserName': 'ThatStunna',
#      'rgUserId': '154155',
#      'siteEntryName': 'ThatStunna'}],
#    'score': 381.25},
#   'complete': True,
#   'prizes': [{'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 10000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 5000},
#    {'value': 2500,
#     'tierPayoutDescriptions': {'Cash': '$2,500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 2500},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 7,
#     'maxFinish': 7,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 8,
#     'maxFinish': 9,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 10,
#     'maxFinish': 14,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 15,
#     'maxFinish': 20,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 21,
#     'maxFinish': 35,
#     'cash': 100},
#    {'value': 80,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'minFinish': 36,
#     'maxFinish': 65,
#     'cash': 80},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 66,
#     'maxFinish': 115,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 116,
#     'maxFinish': 190,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 191,
#     'maxFinish': 290,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 291,
#     'maxFinish': 540,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 541,
#     'maxFinish': 940,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 941,
#     'maxFinish': 1540,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 1541,
#     'maxFinish': 2420,
#     'cash': 15}]},
#  {'_id': '5ae4b6670f94ac3e01472192',
#   'rgPrizePool': 6600,
#   'rgPrizeWinnerCount': 33,
#   'entryCount': 111,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 3,
#   'maxEntries': 111,
#   'entryFee': 100,
#   'name': 'NBA $100 Double Up',
#   'siteContestId': '52063138',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 1,
#     'maxFinish': 50,
#     'cash': 200}]},
#  {'_id': '5ae4b69cdd71203dfc087fe3',
#   'rgPrizePool': 16130,
#   'rgPrizeWinnerCount': 1613,
#   'entryCount': 3448,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 15000,
#   'maxEntriesPerUser': 103,
#   'maxEntries': 3448,
#   'entryFee': 5,
#   'name': 'NBA $5 Double Up',
#   'siteContestId': '52063139',
#   '_slateId': '5aff6348a6b8b14c55464511',
#   'winner': {'users': [], 'score': None},
#   'complete': True,
#   'prizes': [{'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 1,
#     'maxFinish': 1500,
#     'cash': 10}]},
#  {'_id': '5ae4b6d9f69c5a3e00d96c20',
#   'rgPrizePool': 5940,
#   'rgPrizeWinnerCount': 594,
#   'entryCount': 2298,
#   'slateType': 3,
#   'gameCount': 4,
#   'siteSlateId': '17048',
#   'start': '2018-01-02T00:30:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 68,
#   'maxEntries': 2298,
#   'entryFee': 5,
#   'name': 'NBA $5 Double Up',
#   'siteContestId': '52063140',
#   '_slateId': '5aff6348a6b8b14c55464511',
# ...
#     'minFinish': 776,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'value': 2}]},
#  {'_id': '5b80af9526ed4308d96d9a9f',
#   'rgPrizePool': 1702.46,
#   'rgPrizeWinnerCount': 83,
#   'entryCount': 1470,
#   'winner': {'score': 300.25, 'users': [{'siteEntryName': 'mosslefty'}]},
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17085',
#   'start': '2018-01-03T02:00:00.000Z',
#   'sport': 3,
#   'prizePool': 10000,
#   'maxEntriesPerUser': 44,
#   'maxEntries': 1470,
#   'entryFee': 8,
#   'name': 'NBA $10K Excellent 8’s (Turbo)',
#   'siteContestId': '52117444',
#   '_slateId': '5b809fffe5f794085a450270',
#   'complete': True,
#   'prizes': [{'cash': 1000,
#     'maxFinish': 1,
#     'minFinish': 1,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'value': 1000},
#    {'cash': 500,
#     'maxFinish': 2,
#     'minFinish': 2,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'value': 500},
#    {'cash': 350,
#     'maxFinish': 3,
#     'minFinish': 3,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'value': 350},
#    {'cash': 200,
#     'maxFinish': 4,
#     'minFinish': 4,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'value': 200},
#    {'cash': 150,
#     'maxFinish': 5,
#     'minFinish': 5,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'value': 150},
#    {'cash': 125,
#     'maxFinish': 6,
#     'minFinish': 6,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'value': 125},
#    {'cash': 100,
#     'maxFinish': 8,
#     'minFinish': 7,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'value': 100},
#    {'cash': 80,
#     'maxFinish': 10,
#     'minFinish': 9,
#     'tierPayoutDescriptions': {'Cash': '$80.00'},
#     'value': 80},
#    {'cash': 60,
#     'maxFinish': 15,
#     'minFinish': 11,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'value': 60},
#    {'cash': 50,
#     'maxFinish': 25,
#     'minFinish': 16,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'value': 50},
#    {'cash': 40,
#     'maxFinish': 40,
#     'minFinish': 26,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'value': 40},
#    {'cash': 30,
#     'maxFinish': 65,
#     'minFinish': 41,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'value': 30},
#    {'cash': 25,
#     'maxFinish': 100,
#     'minFinish': 66,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'value': 25},
#    {'cash': 20,
#     'maxFinish': 160,
#     'minFinish': 101,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'value': 20},
#    {'cash': 15,
#     'maxFinish': 250,
#     'minFinish': 161,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'value': 15},
#    {'cash': 12,
#     'maxFinish': 395,
#     'minFinish': 251,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'value': 12}]},
#  {'_id': '5ae4c292dd71203dfc285ccf',
#   'rgPrizePool': 0,
#   'rgPrizeWinnerCount': 0,
#   'entryCount': 22,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 6000,
#   'maxEntriesPerUser': 1,
#   'maxEntries': 22,
#   'entryFee': 300,
#   'name': 'NBA $6K 3-Ball [Single Entry] (Night)',
#   'siteContestId': '52117078',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'nmangskau'}],
#    'score': 262},
#   'complete': True,
#   'prizes': [{'value': 2000,
#     'tierPayoutDescriptions': {'Cash': '$2,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 2000},
#    {'value': 1500,
#     'tierPayoutDescriptions': {'Cash': '$1,500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 1500},
#    {'value': 1100,
#     'tierPayoutDescriptions': {'Cash': '$1,100.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 1100},
#    {'value': 800,
#     'tierPayoutDescriptions': {'Cash': '$800.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 800},
#    {'value': 600,
#     'tierPayoutDescriptions': {'Cash': '$600.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 600}]},
#  {'_id': '5ae4c290d69dcc3dfdc368a1',
#   'rgPrizePool': 962.4599999999999,
#   'rgPrizeWinnerCount': 295,
#   'entryCount': 17835,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 15000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 17835,
#   'entryFee': 1,
#   'name': 'NBA $15K And-One (Night)',
#   'siteContestId': '52101778',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'jdubeast'}],
#    'score': 288.5},
#   'complete': True,
#   'prizes': [{'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 500},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 150},
#    {'value': 125,
#     'tierPayoutDescriptions': {'Cash': '$125.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 125},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 16,
#     'maxFinish': 20,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 21,
#     'maxFinish': 30,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 31,
#     'maxFinish': 40,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 41,
#     'maxFinish': 55,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 56,
#     'maxFinish': 75,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 76,
#     'maxFinish': 115,
#     'cash': 15},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 116,
#     'maxFinish': 200,
#     'cash': 10},
#    {'value': 7,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'minFinish': 201,
#     'maxFinish': 315,
#     'cash': 7},
#    {'value': 5,
#     'tierPayoutDescriptions': {'Cash': '$5.00'},
#     'minFinish': 316,
#     'maxFinish': 560,
#     'cash': 5},
#    {'value': 3,
#     'tierPayoutDescriptions': {'Cash': '$3.00'},
#     'minFinish': 561,
#     'maxFinish': 1050,
#     'cash': 3},
#    {'value': 2,
#     'tierPayoutDescriptions': {'Cash': '$2.00'},
#     'minFinish': 1051,
#     'maxFinish': 2150,
#     'cash': 2},
#    {'value': 1.5,
#     'tierPayoutDescriptions': {'Cash': '$1.50'},
#     'minFinish': 2151,
#     'maxFinish': 4450,
#     'cash': 1.5}]},
#  {'_id': '5ae4c2c50f94ac3e0167c738',
#   'rgPrizePool': 1868.4599999999998,
#   'rgPrizeWinnerCount': 109,
#   'entryCount': 3567,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 12000,
#   'maxEntriesPerUser': 20,
#   'maxEntries': 3567,
#   'entryFee': 4,
#   'name': 'NBA $12K Four Point Play [20 Entry Max] (Night)',
#   'siteContestId': '52101779',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'closhardy'}],
#    'score': 281},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 700,
#     'tierPayoutDescriptions': {'Cash': '$700.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 700},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 300},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 7,
#     'maxFinish': 8,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 9,
#     'maxFinish': 10,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 11,
#     'maxFinish': 15,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 16,
#     'maxFinish': 25,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 26,
#     'maxFinish': 35,
#     'cash': 40},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 36,
#     'maxFinish': 45,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 46,
#     'maxFinish': 60,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 61,
#     'maxFinish': 80,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 81,
#     'maxFinish': 115,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 116,
#     'maxFinish': 165,
#     'cash': 12},
#    {'value': 10,
#     'tierPayoutDescriptions': {'Cash': '$10.00'},
#     'minFinish': 166,
#     'maxFinish': 230,
#     'cash': 10},
#    {'value': 8,
#     'tierPayoutDescriptions': {'Cash': '$8.00'},
#     'minFinish': 231,
#     'maxFinish': 330,
#     'cash': 8},
#    {'value': 7,
#     'tierPayoutDescriptions': {'Cash': '$7.00'},
#     'minFinish': 331,
#     'maxFinish': 530,
#     'cash': 7},
#    {'value': 6,
#     'tierPayoutDescriptions': {'Cash': '$6.00'},
#     'minFinish': 531,
#     'maxFinish': 880,
#     'cash': 6}]},
#  {'_id': '5ae4c2fa0f94ac3e01686730',
#   'rgPrizePool': 2245,
#   'rgPrizeWinnerCount': 20,
#   'entryCount': 424,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 12000,
#   'maxEntriesPerUser': 12,
#   'maxEntries': 424,
#   'entryFee': 33,
#   'name': 'NBA $12K Triple Threat (Night)',
#   'siteContestId': '52117080',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'mazwa'},
#     {'rgUserName': 'Bae_Wise',
#      'rgUserId': '151886',
#      'siteEntryName': 'BeatdownBae'}],
#    'score': 271},
#   'complete': True,
#   'prizes': [{'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 500},
#    {'value': 400,
#     'tierPayoutDescriptions': {'Cash': '$400.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 400},
#    {'value': 300,
#     'tierPayoutDescriptions': {'Cash': '$300.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 300},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 6,
#     'maxFinish': 7,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 8,
#     'maxFinish': 11,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 12,
#     'maxFinish': 18,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 19,
#     'maxFinish': 30,
#     'cash': 100},
#    {'value': 75,
#     'tierPayoutDescriptions': {'Cash': '$75.00'},
#     'minFinish': 31,
#     'maxFinish': 50,
#     'cash': 75},
#    {'value': 60,
#     'tierPayoutDescriptions': {'Cash': '$60.00'},
#     'minFinish': 51,
#     'maxFinish': 80,
#     'cash': 60},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 81,
#     'maxFinish': 124,
#     'cash': 50}]},
#  {'_id': '5ae4c3500f94ac3e0169856d',
#   'rgPrizePool': 22322.139999999985,
#   'rgPrizeWinnerCount': 1302,
#   'entryCount': 24780,
#   'slateType': 3,
#   'gameCount': 2,
#   'siteSlateId': '17072',
#   'start': '2018-01-03T03:00:00.000Z',
#   'sport': 3,
#   'prizePool': 200000,
#   'maxEntriesPerUser': 150,
#   'maxEntries': 29411,
#   'entryFee': 8,
#   'name': 'NBA $200K West Coast Special 2018 Tip-Off [$30K to 1st] (Night)',
#   'siteContestId': '52117081',
#   '_slateId': '5ae4c290d69dcc3dfdc3685e',
#   'winner': {'users': [{'rgUserName': None,
#      'rgUserId': None,
#      'siteEntryName': 'rm036'}],
#    'score': 289.5},
#   'complete': True,
#   'prizes': [{'value': 30000,
#     'tierPayoutDescriptions': {'Cash': '$30,000.00'},
#     'minFinish': 1,
#     'maxFinish': 1,
#     'cash': 30000},
#    {'value': 20000,
#     'tierPayoutDescriptions': {'Cash': '$20,000.00'},
#     'minFinish': 2,
#     'maxFinish': 2,
#     'cash': 20000},
#    {'value': 10000,
#     'tierPayoutDescriptions': {'Cash': '$10,000.00'},
#     'minFinish': 3,
#     'maxFinish': 3,
#     'cash': 10000},
#    {'value': 5000,
#     'tierPayoutDescriptions': {'Cash': '$5,000.00'},
#     'minFinish': 4,
#     'maxFinish': 4,
#     'cash': 5000},
#    {'value': 3000,
#     'tierPayoutDescriptions': {'Cash': '$3,000.00'},
#     'minFinish': 5,
#     'maxFinish': 5,
#     'cash': 3000},
#    {'value': 1000,
#     'tierPayoutDescriptions': {'Cash': '$1,000.00'},
#     'minFinish': 6,
#     'maxFinish': 6,
#     'cash': 1000},
#    {'value': 750,
#     'tierPayoutDescriptions': {'Cash': '$750.00'},
#     'minFinish': 7,
#     'maxFinish': 7,
#     'cash': 750},
#    {'value': 500,
#     'tierPayoutDescriptions': {'Cash': '$500.00'},
#     'minFinish': 8,
#     'maxFinish': 9,
#     'cash': 500},
#    {'value': 350,
#     'tierPayoutDescriptions': {'Cash': '$350.00'},
#     'minFinish': 10,
#     'maxFinish': 12,
#     'cash': 350},
#    {'value': 250,
#     'tierPayoutDescriptions': {'Cash': '$250.00'},
#     'minFinish': 13,
#     'maxFinish': 16,
#     'cash': 250},
#    {'value': 200,
#     'tierPayoutDescriptions': {'Cash': '$200.00'},
#     'minFinish': 17,
#     'maxFinish': 25,
#     'cash': 200},
#    {'value': 150,
#     'tierPayoutDescriptions': {'Cash': '$150.00'},
#     'minFinish': 26,
#     'maxFinish': 45,
#     'cash': 150},
#    {'value': 100,
#     'tierPayoutDescriptions': {'Cash': '$100.00'},
#     'minFinish': 46,
#     'maxFinish': 85,
#     'cash': 100},
#    {'value': 70,
#     'tierPayoutDescriptions': {'Cash': '$70.00'},
#     'minFinish': 86,
#     'maxFinish': 135,
#     'cash': 70},
#    {'value': 50,
#     'tierPayoutDescriptions': {'Cash': '$50.00'},
#     'minFinish': 136,
#     'maxFinish': 215,
#     'cash': 50},
#    {'value': 40,
#     'tierPayoutDescriptions': {'Cash': '$40.00'},
#     'minFinish': 216,
#     'maxFinish': 315,
#     'cash': 40},
#    {'value': 35,
#     'tierPayoutDescriptions': {'Cash': '$35.00'},
#     'minFinish': 316,
#     'maxFinish': 440,
#     'cash': 35},
#    {'value': 30,
#     'tierPayoutDescriptions': {'Cash': '$30.00'},
#     'minFinish': 441,
#     'maxFinish': 690,
#     'cash': 30},
#    {'value': 25,
#     'tierPayoutDescriptions': {'Cash': '$25.00'},
#     'minFinish': 691,
#     'maxFinish': 1192,
#     'cash': 25},
#    {'value': 20,
#     'tierPayoutDescriptions': {'Cash': '$20.00'},
#     'minFinish': 1193,
#     'maxFinish': 1787,
#     'cash': 20},
#    {'value': 15,
#     'tierPayoutDescriptions': {'Cash': '$15.00'},
#     'minFinish': 1788,
#     'maxFinish': 3292,
#     'cash': 15},
#    {'value': 12,
#     'tierPayoutDescriptions': {'Cash': '$12.00'},
#     'minFinish': 3293,
#     'maxFinish': 7292,
#     'cash': 12}]}]
